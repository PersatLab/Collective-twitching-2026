# %% [markdown]
# ## Import packages

# %%
#import packages
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import skew
from scipy.interpolate import CubicSpline

# %%
path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data' #address of working directory
data_path = path + '/dataset-processing+revisions'
#data_path = path + '/dataset-WT-quorum'

# create a DataFrame with all experiments data
folder_list = [f for f in os.listdir(data_path) if (os.path.isdir(os.path.join(data_path, f)) and f[:6].isdigit())]
exp = pd.DataFrame(folder_list, columns=['folderpath'])
print(exp.head(5))
# Out:
#                                           folderpath
# 0  260305_436+3121_0p5agarose_OD0p5_10pc_3h_5sec_...
# 1  241018_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...
# 2  241003_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...
# 3  240820_1695_0p55pagarose_2xTrpNC_OD0p5_2h_5s_9...
# 4  260304_337+3120_0p5agarose_OD0p5_10pc_1h30_100...

# %%
exp_date = [exp.folderpath[i][:6] for i in range(len(exp.folderpath))]
exp_strain = [exp.folderpath[i][7:10] for i in range(len(exp.folderpath))]

exp['date'] = exp_date
exp['strain'] = exp_strain
print(exp['strain'])
# Out:
# 0     436
# 1     459
# 2     232
# 3     169
# 4     337
#      ...
# 74    177
# 75    177
# 76    232
# 77    232
# 78    232
# Name: strain, Length: 79, dtype: object

# %% [markdown]
# # 1. Histogram: area

# %% [markdown]
# ## Function

# %%
bin_edges = list(range(100))
bin_edges_norm = list(np.linspace(0,10,101))

def get_area_hist(path, filename, n_strain=0, n_replica=0):
  df = pd.read_csv(path+filename)
  print(df.head(5))
  df.columns = ['cellid', 'area', 'area_mean', 'area_norm']
  #df.columns = ['frame', 'cellid', 'area', 'area_mean', 'area_norm']

  counts, _, _ = plt.hist(df['area'], bins=bin_edges, density=True)
  counts_norm, _, _ = plt.hist(df['area_norm'], bins=bin_edges_norm, density=True)
  plt.close()

  return counts, counts_norm, np.std(df['area']), np.std(df['area_norm']), df['area_norm'].max(), df['area_norm'].mean(), df['area_norm'].quantile(0.95), skew(df['area_norm'].dropna()), df['area_norm'].median()

# %% [markdown]
# ## Loop for all experiments

# %%
# get histogram from all experiments
exp['area_hist'] = [[] for _ in range(len(exp))]
exp['area_hist_norm'] = [[] for _ in range(len(exp))]
exp['area_hist_std'] = [[] for _ in range(len(exp))]
exp['area_hist_norm_std'] = [[] for _ in range(len(exp))]
exp['area_hist_norm_max'] = [[] for _ in range(len(exp))]
exp['area_hist_norm_max-mean'] = [[] for _ in range(len(exp))]
exp['area_hist_norm_cv'] = [[] for _ in range(len(exp))] # coefficient of variation = std / mean
exp['area_hist_norm_95pc'] = [[] for _ in range(len(exp))] # 95th percentile
exp['area_hist_norm_skew'] = [[] for _ in range(len(exp))] # skewness
exp['area_hist_norm_median'] = [[] for _ in range(len(exp))] # median


for n in range(len(exp)):
    #path = path + '/tessellation/'
    path = data_path + '/' +  exp.folderpath[n] + '/tessellation/'
    filename = 'frame_0_voronoi_areas_microns.csv'
    #filename = 'movie_voronoi_areas_microns.csv'
    a, b, c, d, e, f, g, h, i = get_area_hist(path, filename)
    exp.at[n, 'area_hist'] = a
    exp.at[n, 'area_hist_norm'] = b
    exp.at[n, 'area_hist_std'] = c
    exp.at[n, 'area_hist_norm_std'] = d
    exp.at[n, 'area_hist_norm_max'] = e
    exp.at[n, 'area_hist_norm_max'] = e
    exp.at[n, 'area_hist_norm_cv'] = d/f
    exp.at[n, 'area_hist_norm_95pc'] = g
    exp.at[n, 'area_hist_norm_skew'] = h
    exp.at[n, 'area_hist_norm_median'] = i
# Out:
#    Cell ID  Area [microns²]  Mean Area [microns²]  Normalized Area
# 0       57         3.217340              7.774126         0.413852
# 1       59         4.271607              7.774126         0.549465
# 2       65         2.728789              7.774126         0.351009
# 3       67         4.342988              7.774126         0.558646
# 4       68         5.652798              7.774126         0.727130
#    Cell ID  Area [microns²]  Mean Area [microns²]  Normalized Area
# 0       96         2.183377              3.137717         0.695849
# 1      106         2.364716              3.137717         0.753642
# 2      108         1.864642              3.137717         0.594267
# 3      113         2.859229              3.137717         0.911245
# 4      115         2.458527              3.137717         0.783540
#    Cell ID  Area [microns²]  Mean Area [microns²]  Normalized Area
# 0       88         3.070810              4.528524         0.678104
# ...

# %% [markdown]
# # 2. Surface coverage

# %%
# get surface coverage from all experiments
exp['surface_coverage'] = [range(0,len(bin_edges)-1) for _ in range(len(exp))]

for n in range(len(exp)):
  path = data_path + '/' +  exp.folderpath[n] + '/surface_coverage/'
  filename = 'surface_coverage_and_density.csv'
  df = pd.read_csv(path+filename)

  exp.at[n, 'surface_coverage'] = float(df.iloc[:,1])
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/1187848351.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   exp.at[n, 'surface_coverage'] = float(df.iloc[:,1])
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/1187848351.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   exp.at[n, 'surface_coverage'] = float(df.iloc[:,1])
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/1187848351.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   exp.at[n, 'surface_coverage'] = float(df.iloc[:,1])
# ...

# %% [markdown]
# # C. Plots

# %% [markdown]
# # A. Area histogram

# %%
data_plot = pd.DataFrame([], columns=['x', 'y', 'strain'])
#data_plot['x'] = [bin_edges[:-1] for _ in range (len(exp))]
data_plot['x'] = [bin_edges_norm[:-1] for _ in range (len(exp))]
data_plot['y'] = exp['area_hist_norm'] # change depending on column
#data_plot['y'] = exp['area_hist'] # change depending on column
data_plot['strain'] = exp['strain']
data_plot.head(5)
# Out:
#                                                    x  ... strain
# 0  [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5,...  ...    436
# 1  [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5,...  ...    459
# 2  [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5,...  ...    232
# 3  [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5,...  ...    169
# 4  [0.0, 0.1, 0.2, 0.30000000000000004, 0.4, 0.5,...  ...    337
#
# [5 rows x 3 columns]

# %%
# Plot histogram

## Print all curves   
#for n in range(len(data_plot)):
    #plt.plot(data_plot.at[n, 'x'], data_plot.at[n, 'y'])

## Print all the curves from one strain only
for n in range(len(data_plot)):
    if '436' in data_plot['strain'].iloc[n]:
        plt.plot(data_plot.at[n, 'x'], data_plot.at[n, 'y'])
        plt.yscale('log')
        plt.xlabel('Voronoi Area (µm^2)')
        plt.ylabel('Probability')


#plt.legend(exp['strain']+'_'+exp['date'])
plt.show()

# %% [markdown]
# ## STD vs. surface coverage

# %%
# Define colors for each strain
color_map = {'177': 'dimgrey', '232': 'deepskyblue', '459': 'darkorange', '169': 'black'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
for strain in ['177', '232', '459', '169']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_std'], 
                color=color_map[strain], alpha=0.5)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()
    
    # Plot the averages with a red contour
    plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=100, alpha=1, 
                edgecolors='black', linewidths=1.5, label=f'{strain}')
    
# Add legend and labels
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Surface coverage (%)')
plt.ylabel(r'Standard deviation Voronoi Area ($\mu m^2$)')
plt.xlim([0, 85])
plt.ylim([0, 27])

# Save the figure
plt.savefig('./figures/std_norm_area_plot.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/1855337180.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()

# %%
# Define colors for each strain
color_map = {'177': 'black', '232': 'deepskyblue', '459': 'darkorange'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
for strain in ['177', '232', '459']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_norm_std'], 
                color=color_map[strain], alpha=0.5)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_std'].mean()
    
    # Plot the averages with a red contour
    plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=100, alpha=1, 
                edgecolors='black', linewidths=1.5, label=f'{strain}')
    
# Add legend and labels
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Surface coverage (%)')
plt.ylabel(r'Standard deviation Norm. Voronoi Area')
plt.xlim([0, 85])
plt.ylim([0, 0.9])

# Save the figure
plt.savefig('./figures/std_norm_area_plot.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_93355/2308993080.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_std'].mean()

# %%
# Define colors for each strain
color_map = {'177': 'black', '232': 'deepskyblue', '459': 'darkorange'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
for strain in ['177', '232', '459']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_norm_cv'], 
                color=color_map[strain], alpha=0.5)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_cv'].mean()
    
    # Plot the averages with a red contour
    plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=100, alpha=1, 
                edgecolors='black', linewidths=1.5, label=f'{strain}')
    
# Add legend and labels
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Surface coverage (%)')
plt.ylabel(r'Coefficient of Variation Norm. Voronoi Area')
plt.xlim([0, 85])
plt.ylim([0, 0.9])

# Save the figure
plt.savefig('./figures/cv_norm_area_plot.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_93355/675023532.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_cv'].mean()

# %%
# Define colors for each strain
color_map = {'177': 'black', '232': 'deepskyblue', '459': 'darkorange', '104': 'lightgray', '169': 'gray'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(8, 6))  # Optional: Adjust the figure size
for strain in ['177', '232', '459']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_norm_max'], 
                color=color_map[strain], alpha=0.3)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_max'].mean()
    
    # Plot the averages with a red contour
    plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=150, alpha=1, 
                edgecolors='black', linewidths=1.5, label=f'{strain}')
    
# Add legend and labels
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Surface coverage (%)')
plt.ylabel(r'Max Norm. Voronoi Area')
plt.xlim([0, 85])
plt.ylim([2, 10])
#plt.ylim([2, 50])

# Save the figure
plt.savefig('./figures/max_norm_area_plot.png', dpi=300, bbox_inches='tight')  # Save with high resolution

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_93355/1333170889.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_max'].mean()

# %%
# Define colors for each strain
color_map = {'177': 'black', '232': 'deepskyblue', '459': 'darkorange', '104': 'black', '169': 'black'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(2, 6))  # Optional: Adjust the figure size
for strain in ['104']: #['177', '232', '459']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_norm_skew'], 
                color=color_map[strain], alpha=0.3)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_skew'].mean()
    
    # Plot the averages with a red contour
    plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=150, alpha=1, 
                edgecolors='black', linewidths=1.5, label=f'{strain}')
    
# Add legend and labels
#plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xlabel('Surface coverage (%)', fontsize=22, fontweight='bold', fontname='Arial')
plt.ylabel(r'Skewness', fontsize=22, fontweight='bold', fontname='Arial')
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=18)
plt.xlim([45, 95])
plt.xticks(ticks=[70]) 
plt.yticks(ticks=[5, 10, 15, 20]) 
#plt.xlim([0, 85])
#plt.ylim([2, 10])
plt.ylim([5, 20])
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_linewidth(1.25)
plt.gca().spines['bottom'].set_linewidth(1.25)
plt.gca().yaxis.set_minor_locator(plt.FixedLocator([7.5, 12.5, 17.5]))
plt.gca().tick_params(axis='both', which='major', length=7, width=1.25, color='black')
plt.gca().tick_params(axis='both', which='minor', length=4, width=1.25, color='black')

# Save the figure
plt.savefig('./figures/skew_norm_area_plot.png', dpi=300, bbox_inches='tight', transparent = True)  # Save with high resolution

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_93355/4065232326.py:22: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_skew'].mean()

# %%
### Figures - draft

import matplotlib.pyplot as plt
import pandas as pd

# Define colors for each strain
#dimgrey
#color_map = {'177': 'magenta', '232': 'deepskyblue', '459': 'darkorange', '337': 'darksalmon', '436': 'mediumblue', '337': 'darksalmon', '436': 'mediumblue', '313': '#b1e271'} ##c1e895'
color_map = {'177': 'magenta', '232': 'deepskyblue', '459': 'darkorange', '337': 'darksalmon', '436': 'mediumblue', '313': '#b1e271'} ##c1e895'

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(4,4))  # Optional: Adjust the figure size
legend_handles = []  # Store handles manually for legend ordering
legend_labels = []  # Store labels manually for legend ordering

#for strain in ['436', '337']:  # Ensure the correct strain order
#for strain in ['436', '232', '337', '177']:
for strain in ['436', '177', '337']:
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_norm_skew'], 
                color=color_map[strain], s=90, alpha=0.4)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_skew'].mean()
    
    # Assign legend labels in order
    if strain == '177':
        label = 'WT'  
    elif strain == '459':
        label = r'$\Delta\mathit{pilG}$' 
    elif strain == '232':
        label = r'$\Delta\mathit{pilH}$'  
    elif strain == '337':
        label = r'$\Delta\mathit{cpdA}$'
    elif strain == '436':
        label = r'$\Delta\mathit{pilH cyaB}$'
    elif strain == '313':
        label = r'$\Delta\mathit{lasR}$' 

    # Set the alpha based on strain
    if strain == '177':  # WT
        alpha_val = 1.0 #0.6
    else:
        alpha_val = 1.0

    # Plot the averages with a red contour and store the handle for manual legend ordering
    scatter = plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=190, alpha=alpha_val, 
                          edgecolors='black', linewidths=1.5, label=label)
    
    legend_handles.append(scatter)
    legend_labels.append(label)

# Manually set the legend with the correct order
#desired_order = [r'$\Delta\mathit{pilH}$', 'WT', r'$\Delta\mathit{pilG}$', r'$\Delta\mathit{pilA\ cpdA}']
desired_order = [r'$\Delta\mathit{cpdA}$', 'WT', r'$\Delta\mathit{pilH cyaB}$']
#desired_order = [r'$\Delta\mathit{lasR}$',r'$\Delta\mathit{pilH}$', r'$\Delta\mathit{pilH cyaB}$', 'WT', r'$\Delta\mathit{cpdA}$']
ordered_handles_labels = sorted(zip(legend_handles, legend_labels), key=lambda x: desired_order.index(x[1]))
ordered_handles, ordered_labels = zip(*ordered_handles_labels)

plt.legend(ordered_handles, ordered_labels, loc='upper left', fontsize=18, frameon = False, bbox_to_anchor=(-0.05, 1.05)) #fontsize=16

# Add labels and formatting
plt.xlabel('Surface coverage (%)', fontsize=22, fontweight='bold', fontname='Arial')
plt.ylabel(r'Skewness', fontsize=22, fontweight='bold', fontname='Arial')
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=18)
plt.xlim([0, 80])
plt.ylim([0.7, 4.5])

# Customize plot appearance
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_linewidth(1.25)
plt.gca().spines['bottom'].set_linewidth(1.25)
#plt.gca().xaxis.set_minor_locator(plt.FixedLocator([0, 10, 20, 30, 40, 50, 60, 70, 80]))
plt.gca().tick_params(axis='both', which='major', length=7, width=1.25, color='black')
plt.gca().tick_params(axis='both', which='minor', length=4, width=1.25, color='black')
plt.gca().set_box_aspect(1)

#plt.grid(alpha=0.3, linewidth=1)
plt.xticks(ticks=[10, 30, 70]) 
plt.yticks(ticks=[1, 2, 3, 4])  # Ensure y-ticks are properly set

# Save the figure
plt.savefig('./figures/skew_norm_area_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/2401499474.py:34: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_norm_skew'].mean()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define colors for each strain
color_map = {'177': 'dimgrey', '232': 'deepskyblue', '459': 'darkorange', '104': 'lightgray', '169': 'gray', '337': 'darksalmon', '436': 'mediumblue'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(5, 5))  # Optional: Adjust the figure size
legend_handles = []  # Store handles manually for legend ordering
legend_labels = []  # Store labels manually for legend ordering

for strain in ['232', '177', '459']:  # Ensure the correct strain order
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Plot individual points with transparency
    plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_std'], 
                color=color_map[strain], s=90, alpha=0.5)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()
    
    # Assign legend labels in order
    if strain == '177':
        label = 'WT'  
    elif strain == '459':
        label = r'$\Delta\mathit{pilG\ cpdA}$' 
    elif strain == '232':
        label = r'$\Delta\mathit{pilH}$'  

    # Plot the averages with a red contour and store the handle for manual legend ordering
    scatter = plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=190, alpha=1, 
                          edgecolors='black', linewidths=1.5, label=label)
    
    legend_handles.append(scatter)
    legend_labels.append(label)

# Manually set the legend with the correct order
desired_order = [r'$\Delta\mathit{pilH}$', 'WT', r'$\Delta\mathit{pilG\ cpdA}$']
ordered_handles_labels = sorted(zip(legend_handles, legend_labels), key=lambda x: desired_order.index(x[1]))
ordered_handles, ordered_labels = zip(*ordered_handles_labels)

plt.legend(ordered_handles, ordered_labels, loc='upper right', fontsize=18)

# Add labels and formatting
plt.xlabel('Surface coverage (%)', fontsize=22, fontweight='bold', fontname='Arial')
plt.ylabel(r'STD (Raw Voronoi Area)', fontsize=22, fontweight='bold', fontname='Arial')
#plt.ylabel(r'Skewness', fontsize=22, fontweight='bold', fontname='Arial')
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=18)
plt.xlim([0, 80])

# Customize plot appearance
plt.gca().spines['top'].set_linewidth(1.25)
plt.gca().spines['right'].set_linewidth(1.25)
plt.gca().spines['left'].set_linewidth(1.25)
plt.gca().spines['bottom'].set_linewidth(1.25)
plt.gca().yaxis.set_minor_locator(plt.FixedLocator([5, 15, 25]))
plt.gca().tick_params(axis='both', which='major', length=10, width=1.25, color='black')
plt.gca().tick_params(axis='both', which='minor', length=5, width=1.25, color='black')

#plt.grid(alpha=0.3, linewidth=1)
plt.xticks(ticks=[10, 30, 70]) 
#plt.yticks(ticks=[1, 2, 3, 4])  # Ensure y-ticks are properly set
plt.yticks(ticks=[0, 10, 20, 30])

# Save the figure
plt.savefig('./figures/STD_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_29692/3722996740.py:28: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()

# %%
### Figures - draft

import matplotlib.pyplot as plt
import pandas as pd

# Define colors for each strain
color_map = {'177': 'magenta', '232': 'deepskyblue', '459': 'darkorange', '104': 'lightgray', '169': 'gray', '337': 'darksalmon', '436': 'mediumblue'}

# Define bins and labels for surface coverage
bins = [0, 15, 40, 75]  # Define the edges of the bins
bin_labels = [10, 30, 70]  # Labels for the bins

# Add a new column to assign each point to a bin
exp['surface_coverage_bin'] = pd.cut(exp['surface_coverage'], bins=bins, labels=bin_labels)

# Create the plot
plt.figure(figsize=(5, 5))  # Optional: Adjust the figure size
legend_handles = []  # Store handles manually for legend ordering
legend_labels = []  # Store labels manually for legend ordering

for strain in ['232', '177', '459']:  # Ensure the correct strain order
    # Filter the data for the current strain
    strain_data = exp[exp['strain'] == strain]
    
    # Assign legend labels in order
    if strain == '177':
        label = 'WT'  
    elif strain == '459':
        label = r'$\Delta\mathit{pilG\ cpdA}$' 
    elif strain == '232':
        label = r'$\Delta\mathit{pilH}$'  

    z = 3 if strain == '177' else 2
    
    # Plot individual points with transparency
    scatter = plt.scatter(strain_data['surface_coverage'], strain_data['area_hist_std'], 
                color=color_map[strain], s=90, edgecolor = 'black', alpha=0.7, label = label, zorder=z)
    
    # Group by binned surface coverage and calculate the mean
    grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()

    # Plot the averages with a red contour and store the handle for manual legend ordering
    #scatter = plt.scatter(bin_labels, grouped.values, color=color_map[strain], s=190, alpha=1, 
                          #edgecolors='black', linewidths=1.5, label=label)
    
    legend_handles.append(scatter)
    legend_labels.append(label)

# Manually set the legend with the correct order
desired_order = [r'$\Delta\mathit{pilH}$', 'WT', r'$\Delta\mathit{pilG\ cpdA}$']
ordered_handles_labels = sorted(zip(legend_handles, legend_labels), key=lambda x: desired_order.index(x[1]))
ordered_handles, ordered_labels = zip(*ordered_handles_labels)

plt.legend(ordered_handles, ordered_labels, loc='upper right', fontsize=18, frameon = False)

# Add labels and formatting
plt.xlabel('Surface coverage (%)', fontsize=22, fontweight='bold', fontname='Arial')
plt.ylabel(r'STD (Raw Voronoi Area)', fontsize=22, fontweight='bold', fontname='Arial')
#plt.ylabel(r'Skewness', fontsize=22, fontweight='bold', fontname='Arial')
plt.tick_params(axis='x', labelsize=18)
plt.tick_params(axis='y', labelsize=18)
plt.xlim([0, 80])
plt.ylim([0, 25])

# Customize plot appearance
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_linewidth(1.25)
plt.gca().spines['bottom'].set_linewidth(1.25)
plt.gca().yaxis.set_minor_locator(plt.FixedLocator([5, 15, 25]))
plt.gca().tick_params(axis='both', which='major', length=10, width=1.25, color='black')
plt.gca().tick_params(axis='both', which='minor', length=5, width=1.25, color='black')

#plt.grid(alpha=0.3, linewidth=1)
plt.xticks(ticks=[10, 30, 70]) 
#plt.yticks(ticks=[1, 2, 3, 4])  # Ensure y-ticks are properly set
plt.yticks(ticks=[0, 10, 20])

# Save the figure
plt.savefig('./figures/STD_plot.png', dpi=300, bbox_inches='tight', transparent=True)

# Show the plot
plt.show()
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_29692/2301131128.py:40: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = strain_data.groupby('surface_coverage_bin')['area_hist_std'].mean()

# %%
 # boxplot for surface coverage
 sns.boxplot(exp, x='surface_coverage', y='strain', hue='strain', palette="hls")
 sns.stripplot(exp, x='surface_coverage', y='strain', size=4, color=".3")
 plt.show()

 # boxplot for std(voronoi)
 sns.boxplot(exp, x='area_hist_norm_std', y='strain', hue='strain', palette="hls")
 sns.stripplot(exp, x='area_hist_norm_std', y='strain', size=4, color=".3")
 plt.show()

# %%
# Initialize data
data2plot = exp
data2plot = data2plot.sort_values(by=['strain', 'surface_coverage'], axis=0, ascending=True)
data2plot['bin_edges'] = [bin_edges[:-1] for _ in range (len(data2plot))]
data2plot['bin_edges_norm'] = [bin_edges_norm[:-1] for _ in range (len(data2plot))]

# Bin the surface coverage into categories
bins = [0, 25, 60, 100]
bins_label = ['Low', 'Medium', 'High']
data2plot['surface_coverage_bin'] = pd.cut(data2plot['surface_coverage'], bins=bins, labels=bins_label)

# Create a column for combined category
data2plot['strain_surface_coverage'] = data2plot['strain'] + '_' + data2plot['surface_coverage_bin'].astype(str)

data2plot
# Out:
#                                            folderpath  ... strain_surface_coverage
# 55  240815_1047_0p55pagarose_2xTrpNC_OD0p5_1h_5s_3...  ...                 104_Low
# 61  240820_1047_0p55pagarose_2xTrpNC_OD0p5_2h_5s_1...  ...              104_Medium
# 67  240816_1047_0p55pagarose_2xTrpNC_OD0p5_2h55_5s...  ...                104_High
# 3   240820_1695_0p55pagarose_2xTrpNC_OD0p5_2h_5s_9...  ...                 169_Low
# 29  240820_1695_0p55pagarose_2xTrpNC_OD0p5_2h_5s_1...  ...              169_Medium
# ..                                                ...  ...                     ...
# 68  240816_459_0p55pagarose_2xTrpNC_OD0p5_1h30_5s_...  ...                459_High
# 1   241018_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                459_High
# 47  240524_459_0p55agarose_2xTrpNC_OD0p5_2h40_5s_1...  ...                459_High
# 18  240614_459_0p55agarose_2xTrpNC_OD0p5_3h_5s_100...  ...                459_High
# ...

# %% [markdown]
# 1. plot all replicate in gray + mean
# - area
# - area_norm
#
# one figure per strain, per surface coverage
#
# => can be a FacetGrid (x=bin, y=counts)
# X = surface coverage category
# Y = strain

# %%
# Custom function to draw each histogram and an overlay of the mean curve
def plot_records_and_mean(x, y, **kwargs):
  """
  Plots individual records and overlays a mean curve. The function handles both the case
  where there is only one record and the case where there are multiple records. It also
  allows for setting custom x-axis limits via keyword arguments.

  Parameters:
  ----------
  x : list or pandas Series
      List of x-coordinates for the records. If there is a single record, it can be a Series
      of x-values. If there are multiple records, it should be a list of lists/arrays.
  y : list or pandas Series
      List of y-coordinates for the records. If there is a single record, it can be a Series
      of y-values. If there are multiple records, it should be a list of lists/arrays.
  **kwargs : dict, optional
      Additional keyword arguments, including:
      - 'xlim1' (int or float): The lower limit for the x-axis (optional).
      - 'xlim2' (int or float): The upper limit for the x-axis (optional).

  Returns:
  -------
  None
      The function modifies the current matplotlib axis by plotting the individual records
      and overlaying the mean curve for the given data.

  Notes:
  ------
  - If the `x` or `y` inputs contain only one record, the plot will show the data
    without aggregation, and the mean curve will correspond to the given record.
  - If there are multiple records, the function will plot individual records as gray lines
    and overlay a mean curve based on the aggregated data.
  - The x-axis limits can be customized using `xlim1` and `xlim2`. If these are not provided,
    the axis limits will not be adjusted.
  """

  # Extracting xlim from kwargs if it is passed
  xlim1 = kwargs.get('xlim1', None)
  xlim2 = kwargs.get('xlim2', None)
  return_values = kwargs.get('return_values', False)

  fig, ax = plt.subplots(1, 1, figsize=(4,4))
  ax.set_yscale('log')
  #ax.set_xlim(right = 10)
  ax.set_xlim(right = xlim2)
  ax.set_ylim(bottom = 0.001, top = 10)
  #ax.set_xticks([0, 20, 40])
  #ax.set_xticks([0, 50, 100]) 
  ax.set_xticks([0, 5, 10]) 
  plt.gca().xaxis.set_minor_locator(plt.FixedLocator([1, 2, 3, 4, 5, 6, 7, 8, 9]))
  plt.gca().xaxis.set_major_locator(plt.FixedLocator([0, 5, 10]))
  #plt.gca().xaxis.set_major_locator(plt.FixedLocator([0, 50, 100]))
  #plt.gca().xaxis.set_minor_locator(plt.FixedLocator([10, 30]))
  #plt.gca().xaxis.set_minor_locator(plt.FixedLocator([25, 75]))
  #plt.gca().xaxis.set_major_locator(plt.FixedLocator([0, 20, 40]))
  ax.set_xlabel("Norm. Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
  #ax.set_xlabel('') #"Raw Voronoi Area (µm$^2$)", fontsize=22, fontweight='bold', fontname='Arial')
  ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
  ax.tick_params(axis='x', labelsize=18)
  ax.tick_params(axis='y', labelsize=18)
  ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')  # Minor ticks
  ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')  # Major ticks
  ax.spines['top'].set_visible(False)
  ax.spines['right'].set_visible(False)  # Right spine thickness
  ax.spines['left'].set_linewidth(1.25)     # Left spine thickness
  ax.spines['bottom'].set_linewidth(1.25)
  ax.set_box_aspect(1)
  #plt.gca().set_aspect('equal')
  #plt.grid(alpha=0.3, linewidth=1)

  if len(x)==1: # CASE 1: ONLY 1 DATA
    x_mean = x.to_list()[0]
    y_mean = y.to_list()[0]
    ax.plot(x_mean, y_mean, color='red', linewidth=7, label="Mean Curve", zorder = 1)

  else: #CASE 2: MORE THAN 1 DATA
    # Plot individual records
    for x_vals, y_vals in zip(x,y):
      ax.plot(x_vals, y_vals, linestyle='-', linewidth=2, color='gray', alpha=0.5, zorder = 2)

    # Compute mean data
    x_flattened = [val for sublist in x for val in sublist]
    x_mean = sorted(set(x_flattened))

    # Calculate mean y-values for each unique x
    y_mean = [
        np.mean([y_vals[x_vals.index(pt)] for x_vals, y_vals in zip(x, y) if pt in x_vals])
        for pt in x_mean
    ]

    # Plot the mean curve in red
    ax.plot(x_mean, y_mean, color='limegreen', linewidth=3, label="Mean Curve")
    #ax.plot(x_mean, y_mean, color='deepskyblue', linewidth=3, label="Mean Curve")

    # Set x-axis limits if provided
    if xlim1 is not None and xlim2 is not None:
        ax.set_xlim([xlim1, xlim2])

  # Return value of Mean Curve if specified
  if return_values is not False:
    return x_mean, y_mean

  # Save the log-log plot
  save_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/figures/'
  log_file_name = os.path.join(save_path, "tesselation_313_norm_low.png")
  plt.tight_layout()
  plt.savefig(log_file_name, bbox_inches='tight', dpi = 300, transparent=True)
  print("saved")

# %%
# Initialize the FacetGrid object
g = sns.FacetGrid(data2plot, col='strain_surface_coverage', col_wrap=3, sharex=True, sharey=True)

# Draw on FacetGrid
g.map(plot_records_and_mean, 'bin_edges', 'area_hist', xlim1=0, xlim2=50)
# Out:
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# saved
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/1514779230.py:42: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots(1, 1, figsize=(4,4))
# saved

# %%
# Initialize the FacetGrid object -- graphes (1 condition at a time)
#g = sns.FacetGrid(data2plot, col='strain_surface_coverage', col_wrap=3, sharex=True, sharey=True)

data2plot_temp = data2plot[data2plot['strain_surface_coverage']=='313_Low']

plot_records_and_mean(data2plot_temp['bin_edges_norm'], data2plot_temp['area_hist_norm'], ylim1 = 0.001, xlim2 = 10.5)
#plot_records_and_mean(data2plot_temp['bin_edges'], data2plot_temp['area_hist'], ylim1 = 0.0001, ylim2 = 10, xlim2 = 100)
#plot_records_and_mean(data2plot_temp['bin_edges'], data2plot_temp['area_hist'], ylim1 = 0.00001, ylim2 = 10, xlim2 = 40)
# Out:
# saved

# %%
# Custom function to draw each histogram and an overlay of the mean curve
def plot_records_and_mean(x, y, **kwargs):
  """
  Plots individual records and overlays a mean curve. The function handles both the case
  where there is only one record and the case where there are multiple records. It also
  allows for setting custom x-axis limits via keyword arguments.

  Parameters:
  ----------
  x : list or pandas Series
      List of x-coordinates for the records. If there is a single record, it can be a Series
      of x-values. If there are multiple records, it should be a list of lists/arrays.
  y : list or pandas Series
      List of y-coordinates for the records. If there is a single record, it can be a Series
      of y-values. If there are multiple records, it should be a list of lists/arrays.
  **kwargs : dict, optional
      Additional keyword arguments, including:
      - 'xlim1' (int or float): The lower limit for the x-axis (optional).
      - 'xlim2' (int or float): The upper limit for the x-axis (optional).

  Returns:
  -------
  None
      The function modifies the current matplotlib axis by plotting the individual records
      and overlaying the mean curve for the given data.

  Notes:
  ------
  - If the `x` or `y` inputs contain only one record, the plot will show the data
    without aggregation, and the mean curve will correspond to the given record.
  - If there are multiple records, the function will plot individual records as gray lines
    and overlay a mean curve based on the aggregated data.
  - The x-axis limits can be customized using `xlim1` and `xlim2`. If these are not provided,
    the axis limits will not be adjusted.
  """

  # Extracting xlim from kwargs if it is passed
  xlim1 = kwargs.get('xlim1', None)
  xlim2 = kwargs.get('xlim2', None)
  return_values = kwargs.get('return_values', False)

  fig, ax = plt.subplots(1, 1, figsize=(5,5))
  ax.set_yscale('log')
  #ax.set_xlim(left = -0.4)
  ax.set_ylim(bottom = 0.0001)
  plt.gca().xaxis.set_major_locator(plt.FixedLocator([0, 5, 10]))
  plt.gca().xaxis.set_minor_locator(plt.FixedLocator([1, 2, 3, 4, 5, 6, 7, 8, 9]))
  ax.set_xlabel("Normalized Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
  ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
  ax.tick_params(axis='x', labelsize=18)
  ax.tick_params(axis='y', labelsize=18)
  ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')  # Minor ticks
  ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')  # Major ticks
  ax.spines['top'].set_linewidth(1.25) 
  ax.spines['right'].set_linewidth(1.25)  # Right spine thickness
  ax.spines['left'].set_linewidth(1.25)     # Left spine thickness
  ax.spines['bottom'].set_linewidth(1.25)
  #plt.gca().set_aspect('equal')
  plt.grid(alpha=0.3, linewidth=1)
  #ax.set_xticks([])
  #ax.set_yticks([])
  #ax.set_yticklabels([])

  if len(x)==1: # CASE 1: ONLY 1 DATA
    x_mean = x.to_list()[0]
    y_mean = y.to_list()[0]
    ax.plot(x_mean, y_mean, color='black', linewidth=3, label="Mean Curve", zorder = 1)

  else: #CASE 2: MORE THAN 1 DATA
    # Plot individual records
    for x_vals, y_vals in zip(x,y):
      ax.plot(x_vals, y_vals, linestyle='-', linewidth=2, color='gray', alpha=0.5, zorder = 2)

    # Compute mean data
    x_flattened = [val for sublist in x for val in sublist]
    x_mean = sorted(set(x_flattened))

    # Calculate mean y-values for each unique x
    y_mean = [
        np.mean([y_vals[x_vals.index(pt)] for x_vals, y_vals in zip(x, y) if pt in x_vals])
        for pt in x_mean
    ]

    # Plot the mean curve in red
    ax.plot(x_mean, y_mean, color='black', linewidth=3, label="Mean Curve")
    #ax.plot(x_mean, y_mean, color='deepskyblue', linewidth=3, label="Mean Curve")

    # Set x-axis limits if provided
    if xlim1 is not None and xlim2 is not None:
        ax.set_xlim([xlim1, xlim2])

  # Return value of Mean Curve if specified
  if return_values is not False:
    return x_mean, y_mean

  # Save the log-log plot
  save_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/figures/'
  log_file_name = os.path.join(save_path, "tesselation_norm_high.png")
  plt.tight_layout()
  plt.savefig(log_file_name, bbox_inches='tight', dpi = 300, transparent=True)
  print("saved")

# %%
# Initialize the FacetGrid object -- graphes (1 condition at a time)
#g = sns.FacetGrid(data2plot, col='strain_surface_coverage', col_wrap=3, sharex=True, sharey=True)

data2plot_temp = data2plot[data2plot['strain_surface_coverage']=='High']

plot_records_and_mean(data2plot_temp['bin_edges_norm'], data2plot_temp['area_hist_norm'])
# Out:
# saved

# %%
## Test cubic spline interpolation to remove bumpy tails
# Custom function to draw each histogram and an overlay of the mean curve
def plot_records_and_mean(x, y, **kwargs):
  """
  Plots individual records and overlays a mean curve. The function handles both the case
  where there is only one record and the case where there are multiple records. It also
  allows for setting custom x-axis limits via keyword arguments.

  Parameters:
  ----------
  x : list or pandas Series
      List of x-coordinates for the records. If there is a single record, it can be a Series
      of x-values. If there are multiple records, it should be a list of lists/arrays.
  y : list or pandas Series
      List of y-coordinates for the records. If there is a single record, it can be a Series
      of y-values. If there are multiple records, it should be a list of lists/arrays.
  **kwargs : dict, optional
      Additional keyword arguments, including:
      - 'xlim1' (int or float): The lower limit for the x-axis (optional).
      - 'xlim2' (int or float): The upper limit for the x-axis (optional).

  Returns:
  -------
  None
      The function modifies the current matplotlib axis by plotting the individual records
      and overlaying the mean curve for the given data.

  Notes:
  ------
  - If the `x` or `y` inputs contain only one record, the plot will show the data
    without aggregation, and the mean curve will correspond to the given record.
  - If there are multiple records, the function will plot individual records as gray lines
    and overlay a mean curve based on the aggregated data.
  - The x-axis limits can be customized using `xlim1` and `xlim2`. If these are not provided,
    the axis limits will not be adjusted.
  """

  # Extracting xlim from kwargs if it is passed
  xlim1 = kwargs.get('xlim1', None)
  xlim2 = kwargs.get('xlim2', None)
  return_values = kwargs.get('return_values', False)

  fig, ax = plt.subplots(1, 1, figsize=(5,5))
  ax.set_yscale('log')
  #ax.set_xlim(left = -0.4)
  ax.set_ylim(bottom = 0.0001)
  plt.gca().xaxis.set_major_locator(plt.FixedLocator([0, 5, 10]))
  plt.gca().xaxis.set_minor_locator(plt.FixedLocator([1, 2, 3, 4, 5, 6, 7, 8, 9]))
  ax.set_xlabel("Normalized Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
  ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
  ax.tick_params(axis='x', labelsize=18)
  ax.tick_params(axis='y', labelsize=18)
  ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')  # Minor ticks
  ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')  # Major ticks
  ax.spines['top'].set_linewidth(1.25) 
  ax.spines['right'].set_linewidth(1.25)  # Right spine thickness
  ax.spines['left'].set_linewidth(1.25)     # Left spine thickness
  ax.spines['bottom'].set_linewidth(1.25)
  #plt.gca().set_aspect('equal')
  plt.grid(alpha=0.3, linewidth=1)
  #ax.set_xticks([])
  #ax.set_yticks([])
  #ax.set_yticklabels([])

  if len(x)==1: # CASE 1: ONLY 1 DATA
    #x_mean = x.to_list()[0]
    #y_mean = y.to_list()[0]
    x_mean = np.array(x.to_list()[0])
    y_mean = np.array(y.to_list()[0])

    # Remove zero values to avoid interpolation issues
    nonzero_indices = y_mean > 0
    x = x_mean[nonzero_indices]
    y = y_mean[nonzero_indices]

    # Create a cubic spline interpolator
    spline = CubicSpline(x, y, bc_type='natural')

    # Generate smooth values
    x_smooth = np.linspace(x.min(), x.max(), 500)  # 500 points for a smooth curve
    y_smooth = spline(x_smooth)

    ax.plot(x_smooth, y_smooth, color='gray', linewidth=3, label="Mean Curve", zorder = 1)

  else: #CASE 2: MORE THAN 1 DATA
    # Plot individual records
    for x_vals, y_vals in zip(x,y):
      ax.plot(x_vals, y_vals, linestyle='-', linewidth=2, color='gray', alpha=0.5, zorder = 2)

    # Compute mean data
    x_flattened = [val for sublist in x for val in sublist]
    x_mean = sorted(set(x_flattened))

    # Calculate mean y-values for each unique x
    y_mean = [
        np.mean([y_vals[x_vals.index(pt)] for x_vals, y_vals in zip(x, y) if pt in x_vals])
        for pt in x_mean
    ]

    # Plot the mean curve in red
    ax.plot(x_mean, y_mean, color='mediumblue', linewidth=3, label="Mean Curve")
    #ax.plot(x_mean, y_mean, color='deepskyblue', linewidth=3, label="Mean Curve")

    # Set x-axis limits if provided
    if xlim1 is not None and xlim2 is not None:
        ax.set_xlim([xlim1, xlim2])

  # Return value of Mean Curve if specified
  if return_values is not False:
    return x_mean, y_mean

  # Save the log-log plot
  save_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/figures/'
  log_file_name = os.path.join(save_path, "tesselation_norm_high.png")
  plt.tight_layout()
  plt.savefig(log_file_name, bbox_inches='tight', dpi = 300, transparent=True)
  print("saved")

# %%
# Initialize the FacetGrid object -- graphes (1 condition at a time)
#g = sns.FacetGrid(data2plot, col='strain_surface_coverage', col_wrap=3, sharex=True, sharey=True)

data2plot_temp = data2plot[data2plot['strain_surface_coverage']=='High']

plot_records_and_mean(data2plot_temp['bin_edges'], data2plot_temp['area_hist'])
# Out:
# saved

# %%
# Initialize the FacetGrid object
g = sns.FacetGrid(data2plot, col='strain_surface_coverage', col_wrap=3, sharex=True, sharey=True)

# Draw on FacetGrid
g.map(plot_records_and_mean, 'bin_edges_norm', 'area_hist_norm', xlim1=0, xlim2=100)
# Out:
# saved
# saved
# saved
# saved
# saved

# %% [markdown]
# 2. mean histogram with strains combines
# - area
# - area_norm
#
# one figure per surface coverage

# %%
# Compute the mean area_hist for each strain and surface_coverage_bin
#mean_data = data2plot.groupby(['surface_coverage_bin', 'strain']).agg(
    #bin_edges=('bin_edges', 'first'),  # Take the first bin_edges for each group
    #area_hist=('area_hist', lambda x: np.mean(np.array(list(x.tolist())), axis=0))  # Mean of area_hist
    #).reset_index()

#mean_data

# Compute the mean area_hist for each strain and surface_coverage_bin
mean_data = data2plot.groupby(['surface_coverage_bin', 'strain']).agg(
    bin_edges=('bin_edges', 'first'),  # Take the first bin_edges for each group
    area_hist=('area_hist', lambda x: np.mean(np.array(list(x.tolist())), axis=0)),  # Mean of area_hist
    bin_edges_norm=('bin_edges_norm', 'first'),  # Take the first bin_edges_norm for each group
    area_hist_norm=('area_hist_norm', lambda x: np.mean(np.array(list(x.tolist())), axis=0))  # Mean of area_hist_norm
    ).reset_index()

# Associate colormap
mean_data['color'] = mean_data['strain'].map(color_map)

mean_data
# Out:
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_53392/780384218.py:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_data = data2plot.groupby(['surface_coverage_bin', 'strain']).agg(
#    surface_coverage_bin  ...        color
# 0                   Low  ...          NaN
# 1                   Low  ...          NaN
# 2                   Low  ...      magenta
# 3                   Low  ...  deepskyblue
# 4                   Low  ...   darksalmon
# 5                   Low  ...   mediumblue
# 6                   Low  ...   darkorange
# 7                Medium  ...          NaN
# 8                Medium  ...          NaN
# 9                Medium  ...      magenta
# 10               Medium  ...  deepskyblue
# 11               Medium  ...   darksalmon
# ...

# %%
# --per surface coverage, strain overlay--

# Initialize the FacetGrid object with the surface_coverage_bin as columns
g = sns.FacetGrid(mean_data, col='surface_coverage_bin', col_wrap=3, height=4)

# Plot the mean value of area_hist for each strain within each facet
def plot_mean_hist(x, y, strain_color, **kwargs):
    for n in range(len(x)):
      plt.plot(x.iloc[n], y.iloc[n], color=strain_color.iloc[n])
    plt.yscale('log')

# Map the custom plot function onto the FacetGrid
g.map(plot_mean_hist, 'bin_edges', 'area_hist', strain_color=mean_data['color'])
plt.legend(mean_data['strain'].unique())
# Out:
# Traceback (most recent call last):
#
#   Cell In[29], line 13
#     g.map(plot_mean_hist, 'bin_edges', 'area_hist', strain_color=mean_data['color'])
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/seaborn/axisgrid.py:758 in map
#     self._facet_plot(func, ax, plot_args, kwargs)
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/seaborn/axisgrid.py:854 in _facet_plot
#     func(*plot_args, **plot_kwargs)
#
#   Cell In[29], line 9 in plot_mean_hist
#     plt.plot(x.iloc[n], y.iloc[n], color=strain_color.iloc[n])
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/matplotlib/pyplot.py:3794 in plot
#     return gca().plot(
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1779 in plot
#     lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/matplotlib/axes/_base.py:296 in __call__
#     yield from self._plot_args(
# ...

# %%
mean_data
# Out:
#    surface_coverage_bin  ...        color
# 0                   Low  ...          NaN
# 1                   Low  ...          NaN
# 2                   Low  ...      magenta
# 3                   Low  ...  deepskyblue
# 4                   Low  ...   darksalmon
# 5                   Low  ...   mediumblue
# 6                   Low  ...   darkorange
# 7                Medium  ...          NaN
# 8                Medium  ...          NaN
# 9                Medium  ...      magenta
# 10               Medium  ...  deepskyblue
# 11               Medium  ...   darksalmon
# 12               Medium  ...   mediumblue
# 13               Medium  ...   darkorange
# 14                 High  ...          NaN
# 15                 High  ...          NaN
# 16                 High  ...      magenta
# 17                 High  ...  deepskyblue
# 18                 High  ...   darksalmon
# 19                 High  ...   mediumblue
# 20                 High  ...   darkorange
#
# [21 rows x 7 columns]

# %%
import os
import matplotlib.pyplot as plt

# -- per surface coverage, strain overlay --

mean_data_temp = mean_data[mean_data['surface_coverage_bin'] == 'High']

fig, ax = plt.subplots(figsize=(4,4))

# Define strain labels (italic for pilH and pilG cpdA)
strain_labels = {
    '232': r'$\Delta\mathit{pilH}$', 
    '177': 'WT', 
    '459': r'$\Delta\mathit{pilG}$',
    '104': r'$\Delta\mathit{pilA}$',
    '169': r'$\Delta\mathit{pilA\ cpdA}$',
    '337': r'$\Delta\mathit{cpdA}$',
    '436': r'$\Delta\mathit{pilH\ cyaB}$',
    '313': r'$\Delta\mathit{lasR}$'
}

# Define plotting order (WT last to be on top)
plot_order = ['337', '436']
#plot_order = ['232', '459', '436', '337', '177']
#plot_order = ['313', '232', '459', '436', '337', '177']

# Store handles for the legend
legend_handles = {}

# Plot the mean value of area_hist for each strain
for strain in plot_order:
    strain_data = mean_data_temp[mean_data_temp['strain'] == strain]

    for n in range(len(strain_data)):
        line, = ax.plot(
            strain_data.iloc[n]['bin_edges_norm'],
            strain_data.iloc[n]['area_hist_norm'], 
            color=strain_data.iloc[n]['color'],
            linewidth=4,
            label=strain_labels[strain]
        )

    # Store one legend handle per strain (avoid duplicates)
    if strain not in legend_handles:
        legend_handles[strain] = line

# Set log scale, limits, and labels
ax.set_yscale('log')
#ax.set_ylim(0.001, 10)
ax.set_ylim(0.0001, 10)
ax.set_xlabel("Norm. Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
ax.set_xticks([0, 5, 10])
ax.minorticks_on()

# Tick formatting
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')
ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')

# Spine formatting
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_linewidth(1.25)
ax.spines['bottom'].set_linewidth(1.25)

# Make axes square (equal scaling)
ax.set_box_aspect(1)

# Adjust layout
fig.tight_layout()

#plt.gca().tick_params(axis='both', which='major', length=7, width=1.25, color='black')
#plt.gca().tick_params(axis='both', which='minor', length=4, width=1.25, color='black')
#plt.grid(alpha=0.3, linewidth=1)

# Set custom legend order (ΔpilH first, WT second, ΔpilG cpdA third)
ordered_legend_handles = [legend_handles['337'], legend_handles['436']]
ordered_labels = [strain_labels['337'], strain_labels['436']]
#ordered_legend_handles = [legend_handles['232'], legend_handles['177'], legend_handles['459']]
#ordered_labels = [strain_labels['232'], strain_labels['177'], strain_labels['459']]
#ordered_legend_handles = [legend_handles['232'], legend_handles['436'], legend_handles['177'], legend_handles['337']]
#ordered_labels = [strain_labels['232'], strain_labels['436'], strain_labels['177'], strain_labels['337']]
#ordered_legend_handles = [legend_handles['313'], legend_handles['177']]
#ordered_labels = [strain_labels['313'], strain_labels['177']]
# Legend
ax.legend(ordered_legend_handles, ordered_labels, loc='upper right', fontsize=14, frameon=False, bbox_to_anchor=(1.05, 1.05))

# Save the log-log plot
save_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/figures/'
log_file_name = os.path.join(save_path, "tesselation_norm_337-436_density_high.png")
#log_file_name = os.path.join(save_path, "tesselation_norm_177+232_high.png")
plt.savefig(log_file_name, bbox_inches='tight', dpi=300, transparent=True)
print("Saved:", log_file_name)

# Show plot
plt.show()
# Out:
# Saved: /Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/figures/tesselation_norm_337-436_density_high.png

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

def plot_voronoi_area_distribution(folder_path):
    # Strain labels and plot order
    strain_labels = {
        '232': r'$P_{\mathrm{CR}} = 0$', #r'$\Delta\mathit{pilH}$',
        '177': r'$P_{\mathrm{CR}} = 0.2$',
        #'459': r'$P_{\mathrm{CR}} = 0.8$',
        #'104': r'$\Delta\mathit{pilA}$',
        #'169': r'$\Delta\mathit{pilA\ cpdA}$',
    }

    # Order for plotting (controls the layering of lines)
    #plot_order = ['232', '459', '177']
    plot_order = ['232', '177']

    # Order for legend (controls display order in legend)
    #legend_order = ['232', '177', '459']
    legend_order = ['232', '177']

    # Color mapping (add more if needed)
    strain_colors = {
        '232': 'deepskyblue',
        '177': 'magenta',
        '459': 'darkorange',
        '104': 'purple',
        '169': 'green',
    }

    # Dictionary to store data grouped by surface coverage
    grouped_data = {}

    # Get all CSV files in the folder
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

    # Load and organize data
    for file in csv_files:
        filename = os.path.basename(file)
        try:
            parts = filename.replace('.csv', '').split('_')
            sc = [p for p in parts if p.startswith("SC")][0]
            strain = parts[-1]
        except IndexError:
            print(f"Skipping malformed filename: {filename}")
            continue

        if sc not in grouped_data:
            grouped_data[sc] = {}
        if strain not in grouped_data[sc]:
            grouped_data[sc][strain] = []

        df = pd.read_csv(file, header=None)
        grouped_data[sc][strain].append(df)

    # Plot one graph per surface coverage
    for sc, strains_data in grouped_data.items():
        fig, ax = plt.subplots(figsize=(4,4))
        legend_handles = {}

        # Plot curves in the desired order
        for strain in plot_order:
            if strain not in strains_data:
                continue

            for df in strains_data[strain]:
                line, = ax.plot(df[0], df[1],
                                linestyle='--',
                                linewidth=4,
                                color=strain_colors[strain],
                                label=strain_labels[strain])

                if strain not in legend_handles:
                    legend_handles[strain] = line

        # Plot formatting
        ax.set_yscale('log')
        ax.set_ylim(bottom=0.001, top=10)
        ax.set_xlim(left=-0.5, right=10.5)
        ax.set_xlabel('') #"Normalized Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
        ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
        ax.set_xticks([0, 5, 10])
        ax.set_ylabel('')
        #ax.set_yticklabels([])
        ax.minorticks_on()
        ax.tick_params(axis='x', labelsize=18)
        ax.tick_params(axis='y', labelsize=18)
        ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')
        ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_linewidth(1.25)
        ax.spines['bottom'].set_linewidth(1.25)
        ax.set_box_aspect(1)

        # Custom legend order
        ordered_legend_handles = [legend_handles[s] for s in legend_order if s in legend_handles]
        ordered_labels = [strain_labels[s] for s in legend_order if s in legend_handles]
        ax.legend(ordered_legend_handles, ordered_labels,
                  loc='upper right', fontsize=18, frameon=False, bbox_to_anchor=(1.05, 1.05))

        # Save plot
        save_dir = os.path.join(folder_path, "figures")
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, f"tesselation_norm_simus_{sc}.png")
        plt.savefig(save_path, bbox_inches='tight', dpi=300, transparent=True)
        print("Saved:", save_path)

        plt.show()

folder_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/dataset-simulations'  
plot_voronoi_area_distribution(folder_path)
# Out:
# Saved: /Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/dataset-simulations/figures/tesselation_norm_simus_SC10pc.png
# Saved: /Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/dataset-simulations/figures/tesselation_norm_simus_SC70pc.png

# %%
# Initialize the FacetGrid object with the surface_coverage_bin as columns
g = sns.FacetGrid(mean_data, col='surface_coverage_bin', col_wrap=3, height=4)

mean_data[mean_data['surface_coverage_bin'] =='Low']

# Plot the mean value of area_hist for each strain within each facet
def plot_mean_hist(x, y, **kwargs):
    for n in range(len(x)):
        plt.plot(x.iloc[n], y.iloc[n])
        #plt.yscale('log')
        

# Map the custom plot function onto the FacetGrid
g.map(plot_mean_hist, 'bin_edges', 'area_hist')
plt.legend(mean_data['strain'].unique())

# %%
# --per strain, surface coverage overlay--

# Initialize the FacetGrid object with the surface_coverage_bin as columns
g = sns.FacetGrid(mean_data, col='strain', col_wrap=5, height=4)

# Map the custom plot function onto the FacetGrid
g.map(plot_mean_hist, 'bin_edges_norm', 'area_hist_norm', 'color')
plt.legend(mean_data['surface_coverage_bin'].unique())

# Save the figure
plt.savefig('./figures/norm_area_plot_1-plot-per-strain.png', dpi=300, bbox_inches='tight')  # Save with high resolution
plt.savefig('./figures/norm_area_plot_1-plot-per-strain.svg', dpi=300, bbox_inches='tight')  # Save with high resolution

# Show the plot
plt.show()
# Out:
# Traceback (most recent call last):
#
#   Cell In[102], line 7
#     g.map(plot_mean_hist, 'bin_edges_norm', 'area_hist_norm', 'color')
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/seaborn/axisgrid.py:758 in map
#     self._facet_plot(func, ax, plot_args, kwargs)
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/seaborn/axisgrid.py:854 in _facet_plot
#     func(*plot_args, **plot_kwargs)
#
# TypeError: plot_mean_hist() takes 2 positional arguments but 3 were given

# %% [markdown]
# 3. boxplot
#
# - y = STD(area)
# - x = strain with 3 sub box (one for each surface coverage)

# %%
# Create the boxplot
sns.boxplot(data=data2plot, x='strain_surface_coverage', y='area_hist_norm_std')
sns.stripplot(data2plot, x='strain_surface_coverage', y='area_hist_norm_std', size=4, color=".3")

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

def plot_voronoi_area_distribution(folder_path):
    # Strain labels and plot order
    strain_labels = {
        '232': r'$P_{\mathrm{CR}} = 0$', #r'$\Delta\mathit{pilH}$',
        '177': r'$P_{\mathrm{CR}} = 0.2$',
        '337': r'$P_{\mathrm{CR}}=0.2$, $AR=4.95$', #r'$\Delta\mathit{pilH}$',
        '436': r'$P_{\mathrm{CR}}=0$, $AR=3.45$',
        #'459': r'$P_{\mathrm{CR}} = 0.8$',
        #'104': r'$\Delta\mathit{pilA}$',
        #'169': r'$\Delta\mathit{pilA\ cpdA}$',
    }

    # Order for plotting (controls the layering of lines)
    #plot_order = ['232', '459', '177']
    #plot_order = ['232', '177']
    plot_order = ['436', '337']

    # Order for legend (controls display order in legend)
    #legend_order = ['232', '177', '459']
    #legend_order = ['232', '177']
    legend_order = ['337', '436']

    # Color mapping (add more if needed)
    strain_colors = {
        '232': 'deepskyblue',
        '177': 'magenta',
        '459': 'darkorange',
        '104': 'purple',
        '169': 'green',
        '337': 'darksalmon',
        '436': 'mediumblue'
    }

    # Dictionary to store data grouped by surface coverage
    grouped_data = {}

    # Get all CSV files in the folder
    csv_files = glob.glob(os.path.join(folder_path, "*.csv"))

    # Load and organize data
    for file in csv_files:
        filename = os.path.basename(file)
        try:
            parts = filename.replace('.csv', '').split('_')
            sc = [p for p in parts if p.startswith("SC")][0]
            strain = parts[-1]
        except IndexError:
            print(f"Skipping malformed filename: {filename}")
            continue

        if sc not in grouped_data:
            grouped_data[sc] = {}
        if strain not in grouped_data[sc]:
            grouped_data[sc][strain] = []

        df = pd.read_csv(file, header=None)
        grouped_data[sc][strain].append(df)

    # Plot one graph per surface coverage
    for sc, strains_data in grouped_data.items():
        fig, ax = plt.subplots(figsize=(4,4))
        legend_handles = {}

        # Plot curves in the desired order
        for strain in plot_order:
            if strain not in strains_data:
                continue

            for df in strains_data[strain]:
                line, = ax.plot(df[0], df[1],
                                linestyle='--',
                                linewidth=4,
                                color=strain_colors[strain],
                                label=strain_labels[strain])

                if strain not in legend_handles:
                    legend_handles[strain] = line

        # Plot formatting
        ax.set_yscale('log')
        ax.set_ylim(bottom=0.001, top=10)
        ax.set_xlim(left=-0.5, right=10.5)
        ax.set_xlabel('') #"Normalized Voronoi Area", fontsize=22, fontweight='bold', fontname='Arial')
        ax.set_ylabel("Probability", fontsize=22, fontweight='bold', fontname='Arial')
        ax.set_xticks([0, 5, 10])
        ax.set_ylabel('')
        #ax.set_yticklabels([])
        ax.minorticks_on()
        ax.tick_params(axis='x', labelsize=20)
        ax.tick_params(axis='y', labelsize=20)
        ax.tick_params(axis='both', which='minor', length=5, width=1.25, color='black')
        ax.tick_params(axis='both', which='major', length=12, width=1.25, color='black')
        ax.spines['top'].set_visible(False)
        ax.spines['right'].set_visible(False)
        ax.spines['left'].set_linewidth(1.25)
        ax.spines['bottom'].set_linewidth(1.25)
        ax.set_box_aspect(1)

        # Custom legend order
        ordered_legend_handles = [legend_handles[s] for s in legend_order if s in legend_handles]
        ordered_labels = [strain_labels[s] for s in legend_order if s in legend_handles]
        ax.legend(ordered_legend_handles, ordered_labels,
                  loc='upper right', fontsize=18, frameon=False, bbox_to_anchor=(1.2, 1.15))

        # Save plot
        save_dir = os.path.join(folder_path, "figures")
        os.makedirs(save_dir, exist_ok=True)
        save_path = os.path.join(save_dir, f"tesselation_norm_simus_{sc}.png")
        plt.savefig(save_path, bbox_inches='tight', dpi=300, transparent=True)
        print("Saved:", save_path)

        plt.show()

folder_path = '/Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/dataset-simulations-revisions'  
plot_voronoi_area_distribution(folder_path)
# Out:
# Saved: /Users/laureleblanc/Desktop/PersatLAB/5_Analysis/Code/5_Tesselation_processing_data/dataset-simulations-revisions/figures/tesselation_norm_simus_SC70pc.png
