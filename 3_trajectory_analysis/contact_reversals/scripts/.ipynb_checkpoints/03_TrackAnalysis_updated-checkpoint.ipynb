# %% [markdown]
# # Import packages, set directories and options

# %%
# Make local editable packages automatically reload

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Import dependencies

import numpy as np
import pandas as pd
import os
from code_modules import DirectoryManager as dm
from code_modules import VideoSegmentation_01_utils as omnu
from code_modules import TrackAnalysis_03_utils as tu
from code_modules import SegmentationAnalysis_02_utils as sau

# %%
# Set working directory

folder_manager = dm.directory_manager()
print(folder_manager.tracksdir)
# Out:
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks

# %% [markdown]
# # Load tracks and clean up dataframes and display

# %%
# Set pixel scale and frame interval, metadata from the image acquisition

pixel_scale = 0.065 #micron/pixel
frame_interval = 5 #sec

# %%
# Load csv files saved from TrackMate, make sure to save the spot file with a name ending with "_spots.csv"

dataframes = tu.load_csv_files_with_spots(folder_manager.tracksdir)
# Out:
# Loaded 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv with utf-8 encoding
# Loaded 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv with utf-8 encoding
# Loaded 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv with utf-8 encoding
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv with utf-8 encoding
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv with utf-8 encoding
# Loaded 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv with utf-8 encoding
# Loaded 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv with utf-8 encoding

# %%
# Clean all loaded CSV DataFrames, removing unnecessary rows and columns, and preparing them for analysis
# Display number of unique tracks per dataframe

cleaned_dataframes=tu.clean_all_csv(dataframes)
unique_track_counts = tu.count_unique_tracks_all(cleaned_dataframes)
tu.display_all_tracks(cleaned_dataframes, all=False)
# Out:
# Number of unique tracks in 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv: 98
# Number of unique tracks in 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv: 42
# Number of unique tracks in 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv: 220
# Number of unique tracks in 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv: 84
# Number of unique tracks in 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv: 230
# Number of unique tracks in 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv: 364
# Number of unique tracks in 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv: 159
# Displaying data from 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0        4113         0  ...             5.013519  3.075800
# 1        4750         0  ...             5.154283  3.113825
# 2        3236         0  ...             4.941274  3.113825
# 3        4073         0  ...             5.087838  3.124388
# 4        3363         0  ...             4.794631  3.145513
# ...       ...       ...  ...                  ...       ...
# 4508    45215       124  ...             3.327839  2.209675
# 4509    51553       124  ...             3.636921  2.186438
# 4510    51318       124  ...             6.450449  4.301050
# 4511    51503       124  ...             3.431905  2.237138
# 4512    51344       124  ...             3.391785  2.237138
#
# [4513 rows x 10 columns]
# Displaying data from 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0        6858         0  ...             3.899574  2.860325
# 1        7912         0  ...             4.514502  2.915250
# 2        7697         0  ...             4.430387  2.843425
# 3        7500         0  ...             4.578769  2.832863
# 4        7398         0  ...             4.326339  2.815963
# ...       ...       ...  ...                  ...       ...
# 1789    36084        40  ...             5.869941  3.722225
# 1790    35896        40  ...             5.508510  3.775038
# 1791    36071        40  ...             5.482138  3.772925
# 1792    36028        41  ...             6.529002  3.779263
# 1793    36161        41  ...             6.335240  3.760250
#
# [1794 rows x 10 columns]
# Displaying data from 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0      303108         0  ...             4.027495  3.303950
# 1      299824         0  ...             3.936061  3.348313
# 2      304560         0  ...             3.865012  3.373663
# 3      306158         0  ...             4.142097  3.320850
# 4      302946         0  ...             4.108305  3.253250
# ...       ...       ...  ...                  ...       ...
# 9099   374196       281  ...             2.367692  1.922375
# 9100   381519       281  ...             2.289900  1.820975
# 9101   380208       281  ...             2.446055  1.835763
# 9102   373132       281  ...             2.460271  1.736475
# 9103   384103       281  ...             2.342924  1.632963
#
# [9104 rows x 10 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0        6154         0  ...             1.812882  2.042788
# 1        5690         0  ...             1.810203  2.011100
# 2        6103         0  ...             1.815264  2.008988
# 3        6048         0  ...             1.782736  2.040675
# 4        5598         0  ...             1.816493  2.011100
# ...       ...       ...  ...                  ...       ...
# 3868    53747       162  ...             4.018427  3.578575
# 3869    53709       162  ...             3.934164  3.646175
# 3870    53691       162  ...             3.896989  3.629275
# 3871    12859       163  ...             3.339050  3.175088
# 3872    11721       163  ...             3.371414  3.208888
#
# [3873 rows x 10 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0       65578         0  ...             3.102657  2.108275
# 1       74126         0  ...             3.089983  2.087150
# 2       64363         0  ...             2.875542  2.131513
# 3       65721         0  ...             2.917922  2.148413
# 4       65473         0  ...             3.222941  2.082925
# ...       ...       ...  ...                  ...       ...
# 7600   301156       273  ...             4.082431  2.615275
# 7601   349885       273  ...             4.198556  2.425150
# 7602   349759       273  ...             3.971731  2.560350
# 7603   349960       273  ...             3.958934  2.598375
# 7604   351175       273  ...             4.213824  2.589925
#
# [7605 rows x 10 columns]
# Displaying data from 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv:
#        SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0        16387         0  ...             4.943460  2.393462
# 1        16776         0  ...             4.802041  2.461063
# 2        16723         0  ...             5.165847  2.465288
# 3        45963         0  ...             4.392407  2.503312
# 4        57124         0  ...             4.783509  2.473737
# ...        ...       ...  ...                  ...       ...
# 14514   186896       597  ...             4.516318  2.661750
# 14515   184761       597  ...             4.458372  2.756812
# 14516   191283       597  ...             4.550123  2.786387
# 14517   192568       597  ...             3.752527  2.870888
# 14518   183473       597  ...             4.036969  2.805400
#
# [14519 rows x 10 columns]
# Displaying data from 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ...  ELLIPSE_ASPECTRATIO      AREA
# 0        9032         0  ...             3.665748  2.279388
# 1        9497         0  ...             3.977479  2.387125
# 2       11190         0  ...             4.190059  2.334313
# 3        9872         0  ...             3.231700  2.287838
# 4        9797         0  ...             3.896001  2.330088
# ...       ...       ...  ...                  ...       ...
# 5248   249507       156  ...             2.608686  1.508325
# 5249   333250       157  ...             2.855434  1.656200
# 5250   333947       157  ...             5.344946  3.506750
# 5251   307990       158  ...             3.035911  1.797738
# 5252   292997       158  ...             3.149451  1.913925
#
# [5253 rows x 10 columns]

# %%
# Separate splitting tracks

split_dataframes=tu.reindex_split_tracks_all(cleaned_dataframes,track_ids=[],exclude=[])
unique_track_counts = tu.count_unique_tracks_all(split_dataframes)
tu.display_all_tracks(split_dataframes, all=False)
# Out:
# Processing 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv
# Processing 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv
# Processing 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv
# Processing 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv
# Processing 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv
# Processing 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv
# Processing 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv
# Number of unique tracks in 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv: 98
# Number of unique tracks in 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv: 42
# Number of unique tracks in 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv: 234
# Number of unique tracks in 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv: 84
# Number of unique tracks in 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv: 240
# Number of unique tracks in 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv: 368
# Number of unique tracks in 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv: 159
# Displaying data from 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0        4113         0  ...            5.013519  3.075800
# 1        4750         0  ...            5.154283  3.113825
# 2        3236         0  ...            4.941274  3.113825
# 3        4073         0  ...            5.087838  3.124388
# 4        3363         0  ...            4.794631  3.145513
# ...       ...       ...  ...                 ...       ...
# 4508    45215       124  ...            3.327839  2.209675
# 4509    51553       124  ...            3.636921  2.186438
# 4510    51318       124  ...            6.450449  4.301050
# 4511    51503       124  ...            3.431905  2.237138
# 4512    51344       124  ...            3.391785  2.237138
#
# [4513 rows x 11 columns]
# Displaying data from 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0        6858         0  ...            3.899574  2.860325
# 1        7912         0  ...            4.514502  2.915250
# 2        7697         0  ...            4.430387  2.843425
# 3        7500         0  ...            4.578769  2.832863
# 4        7398         0  ...            4.326339  2.815963
# ...       ...       ...  ...                 ...       ...
# 1789    36084        40  ...            5.869941  3.722225
# 1790    35896        40  ...            5.508510  3.775038
# 1791    36071        40  ...            5.482138  3.772925
# 1792    36028        41  ...            6.529002  3.779263
# 1793    36161        41  ...            6.335240  3.760250
#
# [1794 rows x 11 columns]
# Displaying data from 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0      303108         0  ...            4.027495  3.303950
# 1      299824         0  ...            3.936061  3.348313
# 2      304560         0  ...            3.865012  3.373663
# 3      306158         0  ...            4.142097  3.320850
# 4      302946         0  ...            4.108305  3.253250
# ...       ...       ...  ...                 ...       ...
# 9099   374196       281  ...            2.367692  1.922375
# 9100   381519       281  ...            2.289900  1.820975
# 9101   380208       281  ...            2.446055  1.835763
# 9102   373132       281  ...            2.460271  1.736475
# 9103   384103       281  ...            2.342924  1.632963
#
# [9104 rows x 11 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0        6154         0  ...            1.812882  2.042788
# 1        5690         0  ...            1.810203  2.011100
# 2        6103         0  ...            1.815264  2.008988
# 3        6048         0  ...            1.782736  2.040675
# 4        5598         0  ...            1.816493  2.011100
# ...       ...       ...  ...                 ...       ...
# 3868    53747       162  ...            4.018427  3.578575
# 3869    53709       162  ...            3.934164  3.646175
# 3870    53691       162  ...            3.896989  3.629275
# 3871    12859       163  ...            3.339050  3.175088
# 3872    11721       163  ...            3.371414  3.208888
#
# [3873 rows x 11 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0       65578         0  ...            3.102657  2.108275
# 1       74126         0  ...            3.089983  2.087150
# 2       64363         0  ...            2.875542  2.131513
# 3       65721         0  ...            2.917922  2.148413
# 4       65473         0  ...            3.222941  2.082925
# ...       ...       ...  ...                 ...       ...
# 7600   301156       273  ...            4.082431  2.615275
# 7601   349885       273  ...            4.198556  2.425150
# 7602   349759       273  ...            3.971731  2.560350
# 7603   349960       273  ...            3.958934  2.598375
# 7604   351175       273  ...            4.213824  2.589925
#
# [7605 rows x 11 columns]
# Displaying data from 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv:
#        SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0        16387         0  ...            4.943460  2.393462
# 1        16776         0  ...            4.802041  2.461063
# 2        16723         0  ...            5.165847  2.465288
# 3        45963         0  ...            4.392407  2.503312
# 4        57124         0  ...            4.783509  2.473737
# ...        ...       ...  ...                 ...       ...
# 14514   186896       597  ...            4.516318  2.661750
# 14515   184761       597  ...            4.458372  2.756812
# 14516   191283       597  ...            4.550123  2.786387
# 14517   192568       597  ...            3.752527  2.870888
# 14518   183473       597  ...            4.036969  2.805400
#
# [14519 rows x 11 columns]
# Displaying data from 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv:
#       SPOT_ID  TRACK_ID  ... ELLIPSE_ASPECTRATIO      AREA
# 0        9032         0  ...            3.665748  2.279388
# 1        9497         0  ...            3.977479  2.387125
# 2       11190         0  ...            4.190059  2.334313
# 3        9872         0  ...            3.231700  2.287838
# 4        9797         0  ...            3.896001  2.330088
# ...       ...       ...  ...                 ...       ...
# 5248   249507       156  ...            2.608686  1.508325
# 5249   333250       157  ...            2.855434  1.656200
# 5250   333947       157  ...            5.344946  3.506750
# 5251   307990       158  ...            3.035911  1.797738
# 5252   292997       158  ...            3.149451  1.913925
#
# [5253 rows x 11 columns]

# %% [markdown]
# # Get parameters calculated for the spots and the tracks

# %%
# Calculating track parameters for all cleaned dataframes. The function computes various track parameters such as displacement, speed, and angular velocity,
# and applies a minimum frame filter to include only relevant tracks. Results are stored in two dictionaries: all_spots, which contains spot-level data with updated parameters,
# and all_tracks, which contains aggregated track-level data. The pixel_scale and frame_interval parameters are used to scale the measurements appropriately.


all_spots, all_tracks = tu.get_track_parameters_all(split_dataframes, pixel_scale, frame_interval, min_frames=6)
# Out:
# Processing 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots.csv
# Processing 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots.csv
# Processing 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots.csv
# Processing 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots.csv
# Processing 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots.csv
# Processing 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots.csv
# Processing 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots.csv

# %% [markdown]
# # Save dataframes as csv files

# %%
# Save all spot-level and track-level dataframes to CSV files

tu.save_spots_tracks(all_spots, all_tracks, folder_manager.tracksanalysisdir)
# Out:
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1
# Saved spots to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_Spots.csv
# Saved tracks to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_Tracks.csv
# Created directory: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/combined_data
# Combined tracks saved to /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/combined_data/Combined_Tracks.csv

# %% [markdown]
# # Load dataframes for plotting tracks data

# %%
# Load track-level and spot-level dataframes from the specified directory

tracks_dataframes = tu.load_tracks(folder_manager.tracksanalysisdir)
spots_dataframes = tu.load_spots(folder_manager.tracksanalysisdir)

# Load the combined tracks dataframe from the specified directory

loaded_combined_tracks = tu.load_tracks(folder_manager.tracksanalysisdir, load_combined=True)
# Out:
# Loaded 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_Tracks.csv
# Loaded 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_Tracks.csv
# Loaded 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_Tracks.csv
# Loaded 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_Tracks.csv
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_Tracks.csv
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_Tracks.csv
# Loaded 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_Tracks.csv
# Loaded 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_Spots.csv
# Loaded 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_Spots.csv
# Loaded 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_Spots.csv
# Loaded 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_Spots.csv
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_Spots.csv
# Loaded 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_Spots.csv
# Loaded 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1 from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_Spots.csv
# Loading combined tracks data from /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/combined_data/Combined_Tracks.csv

# %%
# Display tracks_dataframes and spots_dataframes

tu.display_all_tracks(tracks_dataframes, all=False)
tu.display_all_tracks(spots_dataframes, all=False)

# Display the combined tracks dataframe

display(loaded_combined_tracks)
# Out:
# Displaying data from 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1:
#                                            IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0   241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.408057
# 1   241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.339647
# 2   241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.056317
# 3   241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.421573
# 4   241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.052098
# ..                                                ...  ...                               ...
# 83  241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.377954
# 84  241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.549728
# 85  241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.610367
# 86  241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.829930
# 87  241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.128730
#
# [88 rows x 17 columns]
# Displaying data from 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1:
#                                            IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.215859
# 1   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.424367
# 2   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.040281
# 3   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.068614
# 4   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.910121
# 5   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.204220
# 6   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.029313
# 7   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.027540
# 8   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.110063
# 9   240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.063965
# 10  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.056259
# 11  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.088194
# 12  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.060939
# 13  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.746587
# 14  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.720410
# 15  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.100590
# 16  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.205668
# 17  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.003529
# 18  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.242753
# 19  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.120042
# 20  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.001441
# 21  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.348339
# 22  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.044231
# 23  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.274292
# 24  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.266210
# 25  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.041833
# 26  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.093555
# 27  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.007260
# 28  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.332770
# 29  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.130749
# 30  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.621709
# 31  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.199885
# 32  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.930921
# 33  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.403400
# 34  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.264822
# 35  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.946860
# 36  240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.538926
#
# [37 rows x 17 columns]
# Displaying data from 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1:
#                                             IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0    241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                          0.017638
# 1    241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                          0.121630
# 2    241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                          0.172096
# 3    241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -0.372355
# 4    241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -0.026194
# ..                                                 ...  ...                               ...
# 191  241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                          4.573062
# 192  241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -7.410225
# 193  241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -3.868030
# 194  241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -0.355379
# 195  241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1...  ...                         -3.337481
#
# [196 rows x 17 columns]
# Displaying data from 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1:
#                                             IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0    240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.551999
# 1    240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                          0.176728
# 2    240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -3.950454
# 3    240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.000519
# 4    240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.055621
# ..                                                 ...  ...                               ...
# 321  240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.012795
# 322  240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.708683
# 323  240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                          0.107231
# 324  240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                          0.829416
# 325  240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix1...  ...                         -0.298616
#
# [326 rows x 17 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1:
#                                             IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0    240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          6.261245
# 1    240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.080932
# 2    240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.056503
# 3    240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.478473
# 4    240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.242475
# ..                                                 ...  ...                               ...
# 190  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.143612
# 191  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.532660
# 192  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.205862
# 193  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.181583
# 194  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          1.451368
#
# [195 rows x 17 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1:
#                                            IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0   240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.521927
# 1   240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.459993
# 2   240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.307773
# 3   240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.156773
# 4   240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.372067
# ..                                                ...  ...                               ...
# 68  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.396134
# 69  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.092968
# 70  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.042237
# 71  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.032486
# 72  240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.532403
#
# [73 rows x 17 columns]
# Displaying data from 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1:
#                                             IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0    240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.157019
# 1    240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.235960
# 2    240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.577214
# 3    240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.452111
# 4    240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          2.040043
# ..                                                 ...  ...                               ...
# 123  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.059309
# 124  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -1.701952
# 125  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.504029
# 126  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          1.642030
# 127  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.760135
#
# [128 rows x 17 columns]
# Displaying data from 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME        MSD
# 0        4113         0            NaN  ...    0.000000             0   0.000000
# 1        4750         0            NaN  ...    0.559784             1   0.347636
# 2        3236         0            NaN  ...    0.537768             2   0.935506
# 3        4073         0            NaN  ...    0.751940             3   1.513521
# 4        3363         0            NaN  ...    0.587934             4   2.110571
# ...       ...       ...            ...  ...         ...           ...        ...
# 4473    45215       124            NaN  ...    1.782661            55  29.191786
# 4474    51553       124            NaN  ...    0.664488            56  31.309789
# 4475    51318       124            NaN  ...    1.482850            57  32.386807
# 4476    51503       124            NaN  ...    1.083397            58  28.192718
# 4477    51344       124            NaN  ...    0.550366            59  27.384118
#
# [4478 rows x 19 columns]
# Displaying data from 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME       MSD
# 0        6858         0            NaN  ...    0.000000             0  0.000000
# 1        7912         0            NaN  ...    0.566536             1  0.084778
# 2        7697         0            NaN  ...    0.004899             2  0.258044
# 3        7500         0            NaN  ...    0.071258             3  0.496755
# 4        7398         0            NaN  ...    0.054634             4  0.794992
# ...       ...       ...            ...  ...         ...           ...       ...
# 1771    32100        38            NaN  ...    0.241333             4  0.222877
# 1772    33227        38            NaN  ...    0.083684             5  0.151671
# 1773    33313        38            NaN  ...    0.219132             6  0.635368
# 1774    33841        38            NaN  ...    0.928004             7  0.752338
# 1775    35364        38            NaN  ...    0.595337             8  0.383742
#
# [1776 rows x 19 columns]
# Displaying data from 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME        MSD
# 0      303108         0            NaN  ...    0.000000             0   0.000000
# 1      299824         0            NaN  ...    0.210977             1   0.359800
# 2      304560         0            NaN  ...    0.353656             2   1.028831
# 3      306158         0            NaN  ...    0.936870             3   1.852598
# 4      302946         0            NaN  ...    0.544740             4   2.691779
# ...       ...       ...            ...  ...         ...           ...        ...
# 8989   374196       281            NaN  ...    1.545184             5  16.863051
# 8990   381519       281            NaN  ...    1.027753             6  20.289575
# 8991   380208       281            NaN  ...    1.557523             7  24.233021
# 8992   373132       281            NaN  ...    0.783857             8  26.935779
# 8993   384103       281            NaN  ...    1.906639             9  26.521319
#
# [8994 rows x 19 columns]
# Displaying data from 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1:
#        SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME        MSD
# 0        16387         0            NaN  ...    0.000000             0   0.000000
# 1        16776         0            NaN  ...    0.631188             1   0.450392
# 2        16723         0            NaN  ...    0.626812             2   1.260531
# 3        45963         0            NaN  ...    1.624552             3   2.275912
# 4        57124         0            NaN  ...    0.710788             4   3.436140
# ...        ...       ...            ...  ...         ...           ...        ...
# 14371   186896       597            NaN  ...    0.236906            54  56.745331
# 14372   184761       597            NaN  ...    0.062882            55  62.175468
# 14373   191283       597            NaN  ...    0.691300            56  66.398876
# 14374   192568       597            NaN  ...    0.623027            57  70.605906
# 14375   183473       597            NaN  ...    0.256284            58  68.423070
#
# [14376 rows x 19 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME         MSD
# 0       65578         0            NaN  ...    0.000000             0    0.000000
# 1       74126         0            NaN  ...    1.316892             1    1.938694
# 2       64363         0            NaN  ...    1.193070             2    5.116421
# 3       65721         0            NaN  ...    1.406018             3    9.500344
# 4       65473         0            NaN  ...    1.590770             4   15.439239
# ...       ...       ...            ...  ...         ...           ...         ...
# 7474   301156       273            NaN  ...    0.390659            20   90.874985
# 7475   349885       273            NaN  ...    0.752121            21   96.774889
# 7476   349759       273            NaN  ...    0.822073            22  109.066365
# 7477   349960       273            NaN  ...    0.917187            23  115.315699
# 7478   351175       273            NaN  ...    0.112685            24  120.103595
#
# [7479 rows x 19 columns]
# Displaying data from 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME       MSD
# 0        6154         0            NaN  ...    0.000000             0  0.000000
# 1        5690         0            NaN  ...    0.044792             1  0.000546
# 2        6103         0            NaN  ...    0.015841             2  0.001512
# 3        6048         0            NaN  ...    0.020147             3  0.002919
# 4        5598         0            NaN  ...    0.031331             4  0.004839
# ...       ...       ...            ...  ...         ...           ...       ...
# 3835    50306       162            NaN  ...    0.372680            55  8.589836
# 3836    53694       162            NaN  ...    0.082899            56  8.763442
# 3837    53747       162            NaN  ...    0.010855            57  8.895334
# 3838    53709       162            NaN  ...    0.071795            58  9.168902
# 3839    53691       162            NaN  ...    0.099533            59  9.097185
#
# [3840 rows x 19 columns]
# Displaying data from 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1:
#       SPOT_ID  TRACK_ID  PREV_TRACK_ID  ...  STEP_SPEED  MSD_LAG_TIME       MSD
# 0        9032         0            NaN  ...    0.000000             0  0.000000
# 1        9497         0            NaN  ...    0.636367             1  0.405856
# 2       11190         0            NaN  ...    0.090000             2  0.759775
# 3        9872         0            NaN  ...    0.106236             3  1.253368
# 4        9797         0            NaN  ...    1.461394             4  1.611968
# ...       ...       ...            ...  ...         ...           ...       ...
# 5151   292441       153            NaN  ...    0.494056             3  0.845247
# 5152   320705       153            NaN  ...    0.350969             4  0.887752
# 5153   322142       153            NaN  ...    0.195404             5  1.348652
# 5154   327516       153            NaN  ...    0.542137             6  2.654297
# 5155   329466       153            NaN  ...    0.430669             7  3.494284
#
# [5156 rows x 19 columns]
#                                              IDENTIFIER  ...  AVERAGE_ANGULAR_VELOCITY_DEG_SEC
# 0     241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.408057
# 1     241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.339647
# 2     241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.056317
# 3     241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                         -0.421573
# 4     241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_m...  ...                          0.052098
# ...                                                 ...  ...                               ...
# 1038  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.059309
# 1039  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -1.701952
# 1040  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          0.504029
# 1041  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                          1.642030
# 1042  240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix...  ...                         -0.760135
#
# [1043 rows x 17 columns]

# %%
# The following columns are available for plotting using the 'tu.raincloud_plot' function:
# Use 'tu.raincloud_plot' to plot and optionally save them
# Replace 'column name' with the column you want to see its distribution

column_names = tu.list_column_names(loaded_combined_tracks)
# Out:
# Available column names:
# IDENTIFIER
# TRACK_ID
# TRACK_FRAME_LENGTH
# TOTAL_DISPLACEMENT_PIX
# TOTAL_DISPLACEMENT_MIC
# END_TO_END_DISTANCE_PIX
# END_TO_END_DISTANCE_MIC
# PERSISTENCE
# SINUOSITY
# MAX_DISTANCE_PIX
# MAX_DISTANCE_MIC
# MEAN_DIRECTIONAL_CHANGE_RAD
# MEAN_DIRECTIONAL_CHANGE_DEG
# SPEED_PIX_FR
# SPEED_MIC_SEC
# AVERAGE_ANGULAR_VELOCITY_RAD_FR
# AVERAGE_ANGULAR_VELOCITY_DEG_SEC

# %%
# Generate a raincloud plot of 'column_names'(variable of choice) against the 'IDENTIFIER'(usually strain or different codition,
# the name will be extracted from the _spots.csv file) from the loaded_combined_tracks DataFrame

tu.raincloud_plot(loaded_combined_tracks, x_col="IDENTIFIER",y_col="SPEED_MIC_SEC", save_dir= folder_manager.tracksanalysisdir, show_outliers=True, save_plot=False)

# %% [markdown]
# # Contact reversals analysis

# %%
## Compute Contact Reversals (CR) and save csv file for manual correction

# Load data
spots_tables = spots_dataframes
segmented_images = omnu.import_image_or_video(folder_manager.segmentdir)

# Initialize a list to collect all dataframes
all_contact_reversals = []

for key, spots_table in spots_tables.items():

    # Classify tracks before computing reversals
    spots_table_classified, subtracks_table = tu.tracks_classification(spots_table, displacement_threshold=5*pixel_scale)
    spots_table_classified.to_csv(folder_manager.tracksanalysisdir + '/' + key + '/' + f"{key}_spots_classified-1.csv", index=False) 
    
    # Search neighbouring cells for tracks with at least 3 consecutive moving frames (defined based on a displacement threshold)
    segmented_image = segmented_images[key + '_segmented.tif']  # Important: the same key from spots_tables is used to get the corresponding segmented image
    subtracks_neighbours = tu.find_neighbours(subtracks_table, segmented_image, pixel_scale) 
    subtracks_neighbours = tu.find_contact_and_measure_angle(subtracks_neighbours, segmented_image)
    subtracks_neighbours.to_csv(folder_manager.tracksanalysisdir + '/' + key + '/' + f"{key}_spots_with_neighbours-2.csv", index=False)

    # Compute reversals for the current spot table
    subtracks_reversals = tu.compute_reversals(subtracks_neighbours)
    subtracks_reversals.to_csv(folder_manager.tracksanalysisdir + '/' + key + '/' + f"{key}_spots_with_reversals-3.csv", index=False)

    # Determine whether there are contact reversals
    subtracks_contact_reversals = tu.find_contact_reversals(subtracks_reversals)
    subtracks_contact_reversals.to_csv(folder_manager.tracksanalysisdir + '/' + key + '/' + f"{key}_spots_with_contact_reversals-4.csv", index=False)

    # Add the current dataframe to the list for combined plotting
    all_contact_reversals.append(subtracks_contact_reversals)

# Combine all dataframes into one
##combined_contact_reversals = pd.concat(all_contact_reversals, ignore_index=True)
# Out:
# Traceback (most recent call last):
#
#   Cell In[29], line 19
#     subtracks_neighbours = tu.find_contact_and_measure_angle(subtracks_neighbours, segmented_image)
#
#   File ~/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/scripts/code_modules/TrackAnalysis_03_utils.py:1543 in find_contact_and_measure_angle
#     long_extremities = sau.find_extremities_of_cells_length(cell_mask)
#
#   File ~/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/scripts/code_modules/SegmentationAnalysis_02_utils.py:100 in find_extremities_of_cells_length
#     for ID in get_cellIDs(mask_frame):
#
#   File ~/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/scripts/code_modules/SegmentationAnalysis_02_utils.py:58 in get_cellIDs
#     return np.unique(mask_frame)[1:].astype(int).tolist()  # Exclude the background value of 0
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/numpy/lib/arraysetops.py:274 in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts,
#
#   File /opt/anaconda3/envs/omnipose/lib/python3.9/site-packages/numpy/lib/arraysetops.py:336 in _unique1d
#     ar.sort()
#
# KeyboardInterrupt

# %%
## Process 'corrected' files to plot CR

#Gather corrected files in one directory
folder_path_corrected = "/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/"
file_path = "/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir"
summary_data_path = file_path + "/summary_data/"
os.makedirs(summary_data_path, exist_ok=True)

# Load data
spots_tables = spots_dataframes
corrected_spots_tables = tu.load_corrected_files(folder_path_corrected)
segmented_images = omnu.import_image_or_video(folder_manager.segmentdir)

# Initialize an empty DataFrame to collect all dataframes
all_contact_reversals = pd.DataFrame()

for key, corrected_spots_table in corrected_spots_tables.items():
    segmented_image = segmented_images[key[:-45] + '_segmented.tif'] 
    df_with_corrected_angles = tu.compute_corrected_contact_angle(corrected_spots_table, segmented_image)
    df_with_corrected_angles = tu.rescale_angle(df_with_corrected_angles)  # rescale between 0° and 90°
    df_with_corrected_angles.to_csv(folder_manager.tracksanalysisdir + '/' + key[:-45] + '/' + f"{key[:-45]}_spots_with_corrected_angles-5.csv", index=False)

    # Add the 'FILE' column to store the corresponding key
    df_with_corrected_angles['FILE'] = key[:-45]
    
    # Append the current dataframe to the combined dataframe
    all_contact_reversals = pd.concat([all_contact_reversals, df_with_corrected_angles], ignore_index=True)
    
    # Summary of the file
    summary_df = tu.save_contact_reversals_data(df_with_corrected_angles, key[:-45], frame_interval)
    print(folder_manager.tracksanalysisdir + '/' + key[:-45] + '/' + f"{key}_summary_contact_reversals-6.csv")
    summary_df.to_csv(folder_manager.tracksanalysisdir + '/' + key[:-45] + '/' + f"{key[:-45]}_summary_contact_reversals-6.csv", index=False)
    summary_df.to_csv(summary_data_path + f"{key[:-45]}_summary_contact_reversals-6.csv", index=False)

# Save the combined dataframe with the 'FILE' column
all_contact_reversals.to_csv(folder_manager.tracksanalysisdir + '/combined_contact_reversals.csv', index=False)

# Plot
tu.plot_contact_reversals(all_contact_reversals, '', save_dir=folder_path_corrected, bin_size=5)

# Summary of the data
summary_df = tu.save_contact_reversals_data(all_contact_reversals, 'global', frame_interval)
summary_df.to_csv(folder_path_corrected + '/summary_contact_reversals-6.csv', index=False)
# Out:
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots_with_contact_reversals-4-corrected.csv
# Successfully loaded: /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/corrected_files/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots_with_contact_reversals-4-corrected.csv
#
#
# File: 240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1.tif
#   Number of tracks: 14
#   Number of tracks with contact reversals: 10
#   Number of contacts: 450.0
#   Number of reversals: 30
#   Number of contact reversals: 24.0
#   Probability of contact reversals (%): 5.333333333333334
#   Total tracked time (in hours): 0.8763888888888889
#   Contacts frequency (/h): 492.9318541996831
#   Reversals frequency (/h): 34.23137876386688
#   Contact reversals frequency (/h): 27.385103011093502
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1.tif
#   Number of tracks: 22
#   Number of tracks with contact reversals: 21
#   Number of contacts: 313.0
#   Number of reversals: 82
#   Number of contact reversals: 78.0
#   Probability of contact reversals (%): 24.920127795527154
#   Total tracked time (in hours): 1.0777777777777777
#   Contacts frequency (/h): 363.7113402061856
#   Reversals frequency (/h): 76.08247422680412
#   Contact reversals frequency (/h): 72.37113402061856
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1/240917_459+2324_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1.tif
#   Number of tracks: 38
#   Number of tracks with contact reversals: 17
#   Number of contacts: 96.0
#   Number of reversals: 42
#   Number of contact reversals: 18.0
#   Probability of contact reversals (%): 18.75
#   Total tracked time (in hours): 1.0819444444444446
#   Contacts frequency (/h): 267.11168164313216
#   Reversals frequency (/h): 38.81899871630295
#   Contact reversals frequency (/h): 16.636713735558406
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1.tif
#   Number of tracks: 55
#   Number of tracks with contact reversals: 49
#   Number of contacts: 882.0
#   Number of reversals: 163
#   Number of contact reversals: 180.0
#   Probability of contact reversals (%): 20.408163265306122
#   Total tracked time (in hours): 2.7
#   Contacts frequency (/h): 439.25925925925924
#   Reversals frequency (/h): 60.37037037037037
#   Contact reversals frequency (/h): 66.66666666666666
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1.tif
#   Number of tracks: 33
#   Number of tracks with contact reversals: 2
#   Number of contacts: 54.0
#   Number of reversals: 36
#   Number of contact reversals: 3.0
#   Probability of contact reversals (%): 5.555555555555555
#   Total tracked time (in hours): 1.0138888888888888
#   Contacts frequency (/h): 151.8904109589041
#   Reversals frequency (/h): 35.50684931506849
#   Contact reversals frequency (/h): 2.9589041095890414
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1.tif
#   Number of tracks: 159
#   Number of tracks with contact reversals: 90
#   Number of contacts: 1093.0
#   Number of reversals: 242
#   Number of contact reversals: 189.0
#   Probability of contact reversals (%): 17.29185727355901
#   Total tracked time (in hours): 5.368055555555555
#   Contacts frequency (/h): 325.07115135834414
#   Reversals frequency (/h): 45.081500646830534
#   Contact reversals frequency (/h): 35.20827943078913
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
# File: 241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1.tif
#   Number of tracks: 76
#   Number of tracks with contact reversals: 26
#   Number of contacts: 274.0
#   Number of reversals: 229
#   Number of contact reversals: 48.0
#   Probability of contact reversals (%): 17.51824817518248
#   Total tracked time (in hours): 2.7208333333333337
#   Contacts frequency (/h): 105.4823889739663
#   Reversals frequency (/h): 84.16539050535987
#   Contact reversals frequency (/h): 17.641653905053598
#
#
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/tracks_analysis/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_spots_with_contact_reversals-4-corrected.csv_summary_contact_reversals-6.csv
#
#
#   Number of tracks: 183
#   Number of tracks with contact reversals: 123
#   Number of contacts: 3162.0
#   Number of reversals: 824
#   Number of contact reversals: 540.0
#   Probability of contact reversals (%): 17.077798861480076
#   Total tracked time (in hours): 15.13611111111111
#   Contacts frequency (/h): 296.31124977060017
#   Reversals frequency (/h): 54.439346669113604
#   Contact reversals frequency (/h): 35.67627087538998

# %%
# Plot summary 

# INPUT USER: MANUALLY add "_SCxxpc_" in the filenames in "summary_data_path"
tu.plot_probability_of_contact_reversals(summary_data_path)
tu.plot_frequency_function_of_SC(summary_data_path)
# Out:
# 2026-05-26 13:40:12,688 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-05-26 13:40:12,688 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-05-26 13:40:12,689 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2026-05-26 13:40:12,690 [INFO] Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/240917_232+2621_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h_5-CH1_SC10pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/240917_459+2624_0p55pagarose_2xTrpNC_OD0p5_mix10pc_5s_2h55_6-CH1_SC70pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_1h30_1001-CH1_SC10pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/240917_177+2618_0p55pagarose_2xTrpNC_OD0p5_mix2pc_5s_2h55_7-CH1_SC70pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/240913_232+2621_0p55agarose_2xTrpNC_OD0p5_mix10pc_5s_2h_6001-CH1_SC70pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/241004_177+2618_0p5pagarose_2xTrpNC_OD0p5_5s_1h_5005-CH1_SC30pc_summary_contact_reversals-6.csv
# /Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/3_trajectory_analysis/contact_reversals/working-dir/summary_data/241004_459+2624_0p5pagarose_2xTrpNC_OD0p5_5s_mix10pc_1h_3-CH1_SC10pc_summary_contact_reversals-6.csv
