# %% [markdown]
# # Compute polarization angle

# %%
# Import packages
import os
import numpy as np
import pandas as pd
import tifffile
import matplotlib.pyplot as plt
from skimage import measure
from skimage.measure import regionprops
from scipy.ndimage import map_coordinates
from scipy.spatial.distance import pdist
from skimage.transform import rotate
from pathlib import Path


# ---------------------------
# USER INPUT
# ---------------------------
INPUT_FOLDER = r"/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/4_polarization_analysis/dataset"
RESULTS_FOLDER = r"/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/4_polarization_analysis/results"
SHOW_PLOTS = True
os.makedirs(RESULTS_FOLDER, exist_ok=True)
# ---------------------------

# ---------------------------
# Helper functions
# ---------------------------
def load_tif_as_channels(path):
    arr = tifffile.imread(path)
    arr = np.asarray(arr)
    if arr.ndim == 3:
        if arr.shape[0] == 3:
            ch0, ch1, ch2 = arr[0], arr[1], arr[2]
        elif arr.shape[2] == 3:
            ch0, ch1, ch2 = arr[...,0], arr[...,1], arr[...,2]
        else:
            raise ValueError(f"Unexpected shape {arr.shape}")
    else:
        raise ValueError(f"Unsupported tif shape: {arr.shape}")
    return ch0.astype(float), ch1.astype(float), ch2.astype(float)

def extract_regions_from_mask(mask_2d):
    return regionprops(mask_2d.astype(np.int32))


def get_single_max_pixel_8connected(region, fluo_raw, max_dist_threshold=10):
    """
    Determine a single "max pixel" per bacterium using 8-connected neighborhood.
    If multiple pixels tie for max average:
        - If distance between any > max_dist_threshold, discard the bacterium (return None)
        - Else, take the centroid of max pixels
    Returns (y_max, x_max, max_avg_intensity) or (None, None, None) if discarded
    """
    mask = np.zeros_like(fluo_raw, dtype=bool)
    coords = region.coords
    mask[coords[:,0], coords[:,1]] = True

    ys, xs = coords[:,0], coords[:,1]
    max_avg = -np.inf
    max_pixels = []

    # Compute 8-connected averages
    for y, x in zip(ys, xs):
        neighbors = [
            (y-1, x-1), (y-1, x), (y-1, x+1),
            (y, x-1),   (y, x),   (y, x+1),
            (y+1, x-1), (y+1, x), (y+1, x+1)
        ]
        vals = [fluo_raw[ny, nx] for ny, nx in neighbors
                if 0 <= ny < fluo_raw.shape[0] and 0 <= nx < fluo_raw.shape[1] and mask[ny, nx]]
        if vals:
            avg_val = np.mean(vals)
            if avg_val > max_avg:
                max_avg = avg_val
                max_pixels = [(y, x)]
            elif avg_val == max_avg:
                max_pixels.append((y, x))

    # Handle multiple max pixels
    if len(max_pixels) == 0:
        return None, None, None
    elif len(max_pixels) == 1:
        return max_pixels[0][0], max_pixels[0][1], max_avg
    else:
        # Compute pairwise distances
        max_pixels_array = np.array(max_pixels)
        dists = pdist(max_pixels_array)
        if len(dists) > 0 and np.any(dists > max_dist_threshold):
            # Discard bacterium
            return None, None, None
        else:
            # Use centroid of max pixels
            y_mean = int(round(np.mean(max_pixels_array[:,0])))
            x_mean = int(round(np.mean(max_pixels_array[:,1])))
            return y_mean, x_mean, max_avg



def estimate_intensity_threshold_from_mask(mask, raw_image, multiplier=1.2):
    labeled_pixels = mask > 0
    if np.any(labeled_pixels):
        mean_region_intensity = np.mean(raw_image[labeled_pixels])
        return mean_region_intensity * multiplier
    else:
        return 0.0

# ---------------------------
# Build files_dict
# ---------------------------
input_path = Path(INPUT_FOLDER)
tif_files = sorted([p for p in input_path.iterdir() if p.suffix.lower() in ('.tif', '.tiff')])

files_dict = {'WT': [], 'pilH': []}
for p in tif_files:
    name = p.name
    if '943' in name:
        files_dict['WT'].append(str(p))
    elif '969' in name:
        files_dict['pilH'].append(str(p))

print(f"Found {len(files_dict['WT'])} WT files and {len(files_dict['pilH'])} pilH files.")

# ---------------------------
# Angle reference dictionary
# ---------------------------
# Key: filename, Value: reference angle in degrees
angle_refs = {
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif": 0.0,
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif": 55.0,
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2012_Composite-final.tif": 0.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3057-Composite-final.tif": 50.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif": 44.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif": 36.0,
}

# ---------------------------
# Prepare dataframes
# ---------------------------
columns = ['bacterium_id', 'angle', 'max_intensity', 'region', 'filename', 'threshold_used']
df_WT = pd.DataFrame(columns=columns)
df_pilH = pd.DataFrame(columns=columns)

# ---------------------------
# Updated process_file() function
# ---------------------------
def process_file(path_str, strain, results_folder, show_plots=True):
    filename_short = Path(path_str).name
    ch0, ch1, ch2 = load_tif_as_channels(path_str)
    edge_seg, core_seg, fluo_raw = ch0, ch1, ch2

    # Label masks
    edge_labels = measure.label(edge_seg > 0) if edge_seg.max() <=1 else edge_seg.astype(int)
    core_labels = measure.label(core_seg > 0) if core_seg.max() <=1 else core_seg.astype(int)

    # Threshold multipliers
    multiplier = 1.2 if strain=='WT' else 1.5
    thr_edge = estimate_intensity_threshold_from_mask(edge_labels, fluo_raw, multiplier)
    thr_core = estimate_intensity_threshold_from_mask(core_labels, fluo_raw, multiplier)

    rows = []
    centroids_kept = []
    max_points_kept = []

    for mask, region_name, thr in [(edge_labels,'edge',thr_edge),(core_labels,'core',thr_core)]:
        for region in extract_regions_from_mask(mask):
            y_max, x_max, max_intensity = get_single_max_pixel_8connected(region, fluo_raw)
            if y_max is None or max_intensity < thr:
                print(f"Discarded region ID {region.label} ({region_name}) in {filename_short}: max < threshold")
                continue
            y0, x0 = region.centroid
            vector = np.array([x_max - x0, y_max - y0])
            angle = np.degrees(np.arctan2(-vector[1], vector[0])) % 360

            # Rescale angle using reference
            ref_angle = angle_refs.get(filename_short, 0.0)
            angle_rescaled = (angle - ref_angle) % 360

            rows.append({
                'bacterium_id': int(region.label),
                'angle': float(angle_rescaled),
                'max_intensity': float(max_intensity),
                'region': region_name,
                'filename': filename_short,
                'threshold_used': float(thr)
            })
            centroids_kept.append((int(round(y0)), int(round(x0))))
            max_points_kept.append((int(round(y_max)), int(round(x_max))))

    # -------------------------------
    # Create RGB overlay
    # -------------------------------
    fluo_norm = np.clip(fluo_raw / np.max(fluo_raw),0,1) if np.max(fluo_raw)>0 else fluo_raw
    rgb = np.stack([fluo_norm, fluo_norm, fluo_norm], axis=-1)

    global_threshold = max(thr_edge, thr_core)
    red_mask = fluo_raw > global_threshold
    rgb[red_mask] = [1.0,0.0,0.0]  # Red

    for (yy, xx) in centroids_kept:
        if 0<=yy<rgb.shape[0] and 0<=xx<rgb.shape[1]:
            rgb[yy, xx] = [0.0,1.0,0.0]  # Green

    for (yy, xx) in max_points_kept:
        if 0<=yy<rgb.shape[0] and 0<=xx<rgb.shape[1]:
            rgb[yy, xx] = [1.0,0.0,1.0]  # Magenta

    rgb_uint8 = (rgb*255).astype(np.uint8)
    save_path = Path(results_folder)/f"{filename_short}_diagnostic_overlay.tif"
    tifffile.imwrite(save_path, rgb_uint8)

    if show_plots:
        plt.figure(figsize=(7,7))
        plt.imshow(rgb)
        plt.title(f"{filename_short}\nRed>threshold, Green=centroid, Magenta=max pixel\nWT=20%, pilH=50%")
        plt.axis('off')
        plt.show()
    else:
        plt.close('all')

    return rows

# ---------------------------
# Main loop
# ---------------------------
for group_key in ('WT','pilH'):
    for fullpath in files_dict[group_key]:
        try:
            rows = process_file(fullpath, group_key, RESULTS_FOLDER, show_plots=SHOW_PLOTS)
            if group_key=='WT':
                df_WT = pd.concat([df_WT,pd.DataFrame(rows)],ignore_index=True)
            else:
                df_pilH = pd.concat([df_pilH,pd.DataFrame(rows)],ignore_index=True)
        except Exception as e:
            print(f"Error processing {fullpath}: {e}")

# Ensure numeric types
for df in (df_WT, df_pilH):
    if not df.empty:
        df['angle'] = pd.to_numeric(df['angle'],errors='coerce')
        df['max_intensity'] = pd.to_numeric(df['max_intensity'],errors='coerce')
        df['threshold_used'] = pd.to_numeric(df['threshold_used'],errors='coerce')

# Save CSVs
df_WT.to_csv(Path(RESULTS_FOLDER)/"df_WT_fluo_vectors.csv",index=False)
df_pilH.to_csv(Path(RESULTS_FOLDER)/"df_pilH_fluo_vectors.csv",index=False)

print("\n✅ Processing complete!")
print(f"WT rows kept: {len(df_WT)}")
print(f"pilH rows kept: {len(df_pilH)}")
# Out:
# Found 3 WT files and 3 pilH files.
# Discarded region ID 20648 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 24520 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 25137 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 30691 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 41352 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45729 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49656 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49881 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54762 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63796 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 10331 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 11738 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 14727 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 15377 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 21376 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 23455 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 25296 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 28198 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 28263 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 30558 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 32313 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 32551 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 33092 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 33699 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 34457 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 34522 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 34717 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 35431 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 35951 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 36536 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 36839 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 37510 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 38095 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 38333 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 38788 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 39590 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 40066 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 40088 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 40456 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 40889 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 40997 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 42037 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 42816 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 42990 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 43011 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 43098 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 43726 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 43899 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 44203 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 44397 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 44484 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 44722 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45004 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45091 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45220 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45350 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45524 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45589 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45632 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45675 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45697 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 45892 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46022 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46043 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46065 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46152 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46563 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46585 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 46845 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47018 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47040 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47126 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47321 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47429 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47624 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 47841 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 48296 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 48599 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49140 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49314 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49747 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49877 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49898 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 49985 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 50765 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 50808 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51068 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51176 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51414 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51566 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51653 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 51783 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52107 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52216 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52302 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52389 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52541 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 52562 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53320 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53385 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53450 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53515 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53667 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53818 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 53905 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54035 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54403 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54446 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54468 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54533 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54641 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54728 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54836 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54858 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54901 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54923 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54945 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 54988 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 55161 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 55399 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 55529 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 55746 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56114 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56179 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56222 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56266 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56309 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56374 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56526 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 56785 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57219 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57349 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57392 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57435 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57847 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 57998 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58496 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58518 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58605 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58756 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58778 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58800 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58821 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58865 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58973 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 58994 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 59146 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 59341 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 59449 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 59601 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 59839 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60077 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60164 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60186 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60229 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60294 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60467 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60532 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60684 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60727 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 60814 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61009 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61117 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61160 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61182 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61247 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61269 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61312 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61355 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61463 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61528 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61593 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61723 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61767 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 61788 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62156 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62200 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62330 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62611 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62720 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62741 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62806 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62893 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 62936 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63261 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63434 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63456 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63737 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63802 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 63911 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64019 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64452 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64495 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64539 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64582 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64647 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64669 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 64885 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# Discarded region ID 65275 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif: max < threshold
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_23793/592365562.py:229: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_WT = pd.concat([df_WT,pd.DataFrame(rows)],ignore_index=True)
# Discarded region ID 2433 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 2717 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 2970 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 4013 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 4708 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 6667 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 7173 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 8974 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 10554 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 10712 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 10775 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 11944 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 12323 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 17190 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 19749 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 20539 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 22308 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 25626 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 28059 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 28944 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 30398 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 30998 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 31788 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 32641 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 32736 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 33621 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 33747 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 35643 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 37886 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 39719 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42689 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 43069 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 43606 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 43859 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 44838 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 51126 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53464 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56845 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 58299 (edge) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 5057 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 7365 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 9829 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 10503 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 10529 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 15379 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 16001 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 16909 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 19762 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 23003 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 23366 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 24871 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 26556 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 28216 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 28398 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 28579 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 29150 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 29176 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 29668 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 30550 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 30758 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 31380 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 32495 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 33221 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 33844 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 34103 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 34285 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 34311 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 34855 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 35529 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 36333 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 36541 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 36567 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 36645 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 37241 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 37319 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 37423 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 37500 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 38304 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 38823 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 38953 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 39108 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 39445 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 39679 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 39783 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40068 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40146 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40353 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40405 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40431 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40483 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 40535 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 41209 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 41416 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 41702 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 41831 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 41987 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42065 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42117 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42220 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42298 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42350 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42376 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42454 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42558 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42583 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42609 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 42895 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 43362 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 44321 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 44529 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 44710 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 44943 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 45021 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 45177 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 45281 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 45307 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 45877 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 46007 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 46733 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 46811 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 46889 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 46992 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47044 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47122 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47303 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47511 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47589 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47692 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47952 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 47978 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48004 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48030 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48056 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48211 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48522 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48626 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48652 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 48782 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 49223 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 49352 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 49949 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50001 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50078 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50182 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50390 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50493 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50597 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50830 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 50856 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 51608 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 51842 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 52438 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 52490 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53139 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53190 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53424 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53579 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 53968 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54046 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54072 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54124 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54228 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54332 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54409 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 54876 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 55680 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 55784 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 55914 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56225 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56277 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56614 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56692 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56769 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56795 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56847 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56925 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 56977 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57055 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57236 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57262 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57340 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57495 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57625 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# Discarded region ID 57729 (core) in 251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif: max < threshold
# ...
# Discarded region ID 65384 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3057-Composite-final.tif: max < threshold
# /var/folders/6n/9gbq90b95yggb0kc46nkmg8c0000gn/T/ipykernel_23793/592365562.py:231: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_pilH = pd.concat([df_pilH,pd.DataFrame(rows)],ignore_index=True)
# Discarded region ID 960 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 1536 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 2624 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 3008 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 5248 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 13760 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 20928 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 21760 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 35647 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 40319 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 40575 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 40703 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 42559 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 45503 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 45695 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 48511 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 51903 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 52735 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 55423 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 7684 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 11367 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 14542 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 16003 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 16511 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 22607 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 24449 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 24639 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 26862 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 28703 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 29402 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 32005 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 32577 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 33276 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 33466 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 38610 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 39689 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 41023 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 42356 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 42674 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 43881 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 44008 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 44643 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 47056 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 51247 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 51628 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 51818 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 53279 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 54358 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 54485 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 54740 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 56137 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 56581 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 57788 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 58232 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 60010 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 61090 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 62804 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 62868 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 63122 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif: max < threshold
# Discarded region ID 1498 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2068 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2211 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 4065 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 5348 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 6061 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 6204 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 6846 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 7060 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 7202 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 8629 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 9698 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 9770 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 10055 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 11909 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 15831 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 16188 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 19682 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 20252 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 20894 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 23461 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 24103 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 26528 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 29808 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 31377 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 32732 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 39720 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 42929 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 43286 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 43642 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 46210 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 48064 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 49633 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 50203 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 52128 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 54197 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 59901 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 62255 (edge) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 788 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 1074 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 1146 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 1432 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 1862 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2364 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2435 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2507 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 2865 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 3295 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 3510 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 4011 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 4870 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 5228 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 5873 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 6804 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 7950 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 8022 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 8165 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 8738 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 11531 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 12319 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 12462 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 14253 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 14325 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 14683 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold
# Discarded region ID 16402 (core) in 251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif: max < threshold

# %% [markdown]
# # Check rotation angles

# %%
### Just to check the rotation

# ---------------------------
# USER INPUT
# ---------------------------
INPUT_FOLDER = r"/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/4_polarization_analysis/dataset"   # <- change this
angle_refs = {
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2003_Composite-final.tif": 0.0,
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2006_Composite-final.tif": 55.0,
    "251007-1_943_0p5agarose_LB_OD0p5_5s_4h30_100X_2012_Composite-final.tif": 0.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3057-Composite-final.tif": 50.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3062-Composite-final.tif": 44.0,
    "251007-2_969_0p5agarose_LB_OD0p5_5s_4h30_100X_3072-Composite-final.tif": 36.0,
}

# ---------------------------
# Helper function to load 3-channel TIFF
# ---------------------------
def load_third_channel(path):
    img = tifffile.imread(path)
    img = np.asarray(img)
    if img.ndim == 3:
        if img.shape[0] == 3:
            ch3 = img[2]
        elif img.shape[2] == 3:
            ch3 = img[...,2]
        else:
            raise ValueError(f"Unexpected image shape: {img.shape}")
    else:
        raise ValueError("Image does not have 3 channels")
    return ch3

# ---------------------------
# Batch process and plot
# ---------------------------
input_path = Path(INPUT_FOLDER)
tif_files = sorted([p for p in input_path.iterdir() if p.suffix.lower() in ('.tif','.tiff')])

for file_path in tif_files:
    filename_short = file_path.name
    ch3 = load_third_channel(file_path)
    
    # Get reference angle, default to 0 if not found
    ref_angle = angle_refs.get(filename_short, 0.0)
    
    # Rotate
    ch3_rot = rotate(ch3, -ref_angle, resize=False, preserve_range=True)
    
    # Plot
    plt.figure(figsize=(6,6))
    plt.imshow(ch3_rot, cmap='gray')
    plt.tight_layout()
    plt.title(f"{filename_short}\nRotated by {ref_angle}°")
    plt.axis('off')
    plt.show()

# %% [markdown]
# # Polarization angles

# %%
#Plot polarization angles in polar plots 
# ---------------------------
# USER INPUT
# ---------------------------
CSV_FOLDER = r"/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/4_polarization_analysis/results"
OUTPUT_FOLDER = r"/Users/laureleblanc/Desktop/Collective-twitching-2026/experiments/4_polarization_analysis/figures"
Path(OUTPUT_FOLDER).mkdir(parents=True, exist_ok=True)

# CSV filenames
csv_WT = Path(CSV_FOLDER)/"df_WT_fluo_vectors.csv"
csv_pilH = Path(CSV_FOLDER)/"df_pilH_fluo_vectors.csv"

# ---------------------------
# Load CSVs
# ---------------------------
df_raw_WT = pd.read_csv(csv_WT)
df_raw_pilH = pd.read_csv(csv_pilH)

# ---------------------------
# Group by region
# ---------------------------
df_WT_edge = df_raw_WT[df_raw_WT['region']=='edge']
df_WT_core = df_raw_WT[df_raw_WT['region']=='core']

df_pilH_edge = df_raw_pilH[df_raw_pilH['region']=='edge']
df_pilH_core = df_raw_pilH[df_raw_pilH['region']=='core']

# ---------------------------
# Function to plot polar histogram
# ---------------------------
def plot_polar_hist(df1, df2, color1, color2, label1, label2, output_prefix, num_bins=36, font_size=16):
    """
    Plot a polar histogram comparing two angle distributions.

    Parameters:
    -----------
    df1, df2 : DataFrames with 'angle' column
    color1, color2 : str
        Colors for the two datasets
    label1, label2 : str
        Labels for legend
    output_prefix : Path
        Base path for saving
    num_bins : int, optional
        Number of bins (default 36)
    font_size : int, optional
        Base font size for labels, ticks, legend, and title
    """
    hist1, bin_edges = np.histogram(df1['angle'], bins=num_bins, range=(0,360), density=True)
    hist2, _ = np.histogram(df2['angle'], bins=num_bins, range=(0,360), density=True)
    bin_centers = np.deg2rad((bin_edges[:-1] + bin_edges[1:])/2)
    
    plt.figure(figsize=(5,5))
    ax = plt.subplot(111, polar=True)
    ax.bar(bin_centers, hist1, width=2*np.pi/num_bins, bottom=0.0, align='center', color=color1, alpha=0.5, label=label1)
    ax.bar(bin_centers, hist2, width=2*np.pi/num_bins, bottom=0.0, align='center', color=color2, alpha=0.5, label=label2)
    
    ax.spines['polar'].set_visible(False)
    ax.set_yticks([0.005, 0.01])
    ax.set_ylim(0, 0.0105)
    ax.yaxis.grid(True, color='black', linewidth=1.5)
    ax.yaxis.grid(True, which='minor', color='black', linewidth=1.5)
    ax.set_yticklabels([0.005, 0.01], fontsize=font_size)
    ax.tick_params(axis='x', labelsize=font_size)
    ax.legend(loc='center left', bbox_to_anchor=(1.2, 0.5), frameon=False, fontsize=font_size)

    #plt.tight_layout()
    plt.savefig(output_prefix.with_suffix(".png"), transparent=True, dpi=300, bbox_inches="tight")
    plt.show()


# ---------------------------
# Plot 4 figures
# ---------------------------

# Figure 1: WT core (gray) vs WT edge (magenta)
plot_polar_hist(df_WT_core, df_WT_edge,
                color1='gray', color2='magenta',
                label1='WT, Core', label2='WT, Edge',
                output_prefix=Path(OUTPUT_FOLDER)/"WT_core_vs_edge")

# Figure 2: pilH core (gray) vs pilH edge (deepskyblue)
plot_polar_hist(df_pilH_core, df_pilH_edge,
                color1='gray', color2='deepskyblue',
                label1=r'$\Delta\mathit{pilH}$, Core', label2=r'$\Delta\mathit{pilH}$, Edge',
                output_prefix=Path(OUTPUT_FOLDER)/"pilH_core_vs_edge")

# Figure 3: pilH edge (deepskyblue) vs WT edge (magenta)
plot_polar_hist(df_pilH_edge, df_WT_edge,
                color1='deepskyblue', color2='magenta',
                label1=r'$\Delta\mathit{pilH}$, Edge', label2='WT, Edge',
                output_prefix=Path(OUTPUT_FOLDER)/"pilH_edge_vs_WT_edge")

# Figure 4: pilH core (deepskyblue) vs WT core (magenta)
plot_polar_hist(df_pilH_core, df_WT_core,
                color1='deepskyblue', color2='magenta',
                label1=r'$\Delta\mathit{pilH}$, Core', label2='WT, Core',
                output_prefix=Path(OUTPUT_FOLDER)/"pilH_core_vs_WT_core")
